# %%
from splinter import Browser
from bs4 import BeautifulSoup

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = "https://www.dhamma.org/en-US/courses/search"
browser.visit(url)

# %%
soup = BeautifulSoup(browser.html, 'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1, maximum-scale=1" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    Vipassana Meditation
#   </title>
#   <meta content="Homepage of Vipassana Meditation as taught by S.N. Goenka in the tradition of Sayagyi U Ba Khin" name="Description"/>
#   <meta content="vipassana,meditation,mindfulness,meditate,goenka,buddha,buddhism,dharma,dhamma,silent retreat,silence,tranquility,insight,stress,mind,religion,spirituality,concentration,samadhi,art of living,compassion,peace,harmony,well-being,mental purification,kindness,empathy,sila,panna,metta" name="Keywords"/>
#   <meta content="app-id=1127952631" name="apple-itunes-app"/>
#   <link href="/assets/bodhileaf-4bb63faac0c10feda2a43c1f44d667a8.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://cdnjs.cloudflare.com/ajax/libs/select2/3.5.2/select2.min.css" rel="stylesheet"/>
#   <link href="/assets/application-39020c21d0a2c583d906ea4c88b12dfc.css" media="all" rel="stylesheet"/>
#   <link href="/assets/application.print-f49d1c3fe1d26fc9b38aff3e55a35b85.css" media="print" rel="stylesheet"/>
#   <!--[if IE 7]>
#     <link rel="stylesheet" media="all" href="/assets/application.ie7-08efc4108d9bc12343d7b6d9d2569365.css" />
#     <![endif]-->
#   <!--[if lte IE 8]>
#     <link rel="stylesheet" media="screen" href="/assets/application.ielte8-b1461367d39add6d24b415e56165c203.css" />
#     <![endif]-->
#   <!--[if lt IE 9]>
#     <script src="/assets/html5shiv-6f1980c2b57c886b7b945ba935b65c90.js"></script>
#     <script src="/assets/respond.1.4-ec962dbbf7e6e837bd18f42bddfc8b31.js"></script>
#     <![endif]-->
#   <script async="" src="https://ssl.google-analytics.com/ga.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var _gaq = _gaq || [];
#       _gaq.push(['_setAccount', 'UA-29271111-1']);
#       _gaq.push(['_setDomainName', 'dhamma.org']);
#       _gaq.push(['_trackPageview']);
#
#       (function() {
#         var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#         ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#         var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#       })();
#   </script>
#  </head>
#  <body class=" controller-courses_search action-index" data-locale="en-US" style="">
#   <div id="precontainer">
#    <div class="modal" id="share-modal">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button aria-hidden="true" class="close" data-dismiss="modal" type="button">
#         ×
#        </button>
#        Share Results
#       </div>
#       <div class="modal-body">
#        <p>
#         To share the course search results, copy and share the link below. This link will expire after seven days from today.
#        </p>
#        <textarea class="form-control" data-bind="text: shareUrl()" rows="4">https://www.dhamma.org/en-US/courses/search?share=null</textarea>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="visible-xs" id="mobile-nav-container">
#    <nav class="navbar navbar-default" role="navigation">
#     <div class="container-fluid">
#      <button class="navbar-toggle" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" type="button">
#       <span class="sr-only">
#        Toggle navigation
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#      </button>
#      <div class="navbar-collapse-container">
#       <div class="navbar-collapse">
#        <ul class="nav navbar-nav">
#         <li id="nav-home">
#          <a class="dropdown-toggle" data-original-title="Home" href="/en-US/index" title="">
#           <i class="glyphicon glyphicon-home">
#           </i>
#          </a>
#         </li>
#         <li class="dropdown" id="nav-about">
#          <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#           About
#          </a>
#          <ul class="dropdown-menu" id="about-menu">
#           <li>
#            <a href="/en-US/about/vipassana">
#             What is Vipassana?
#            </a>
#           </li>
#           <li>
#            <a href="/en-US/about/goenka">
#             Mr. S.N. Goenka
#            </a>
#           </li>
#           <li>
#            <a href="/en-US/about/art">
#             The Art of Living: Vipassana Meditation
#            </a>
#           </li>
#           <li>
#            <a href="/en-US/about/code">
#             The Code of Discipline
#            </a>
#           </li>
#           <li>
#            <a href="/en-US/about/qanda">
#             Questions &amp; Answers About the Technique of Vipassana Meditation
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="dropdown" id="nav-courses">
#          <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#           Courses
#          </a>
#          <ul class="dropdown-menu" id="courses-menu">
#           <li>
#            <a href="/en-US/courses/search" rel="nofollow">
#             Search
#            </a>
#           </li>
#           <li class="dropdown">
#            <a href="/en-US/courses/glossary" rel="nofollow">
#             Glossary
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="dropdown" id="nav-locations">
#          <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#           Locations
#          </a>
#          <ul class="dropdown-menu" id="resources-menu">
#           <li>
#            <a href="/en-US/locations/directory" rel="nofollow">
#             Worldwide Directory
#            </a>
#           </li>
#           <li class="dropdown">
#            <a class="dropdown-toggle" href="/en-US/maps#001" rel="nofollow">
#             Maps
#            </a>
#           </li>
#           <li>
#            <a href="/en-US/locations/contacts" rel="nofollow">
#             Contacts
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="dropdown" id="nav-special-sites">
#          <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#           Special Sites
#          </a>
#          <ul class="dropdown-menu" id="special-sites-menu">
#           <li>
#            <a href="/os/" target="_blank">
#             For Old Students
#            </a>
#           </li>
#           <li>
#            <a href="http://www.executive.dhamma.org/" target="_blank">
#             Vipassana for Executives
#            </a>
#           </li>
#           <li>
#            <a href="http://www.prison.dhamma.org/" target="_blank">
#             Vipassana for Prisons
#            </a>
#           </li>
#           <li>
#            <a href="http://www.children.dhamma.org/" target="_blank">
#             Children's Courses
#            </a>
#           </li>
#           <li>
#            <a href="https://www.dhamma.org/en/vri.htm" target="_blank">
#             Vipassana Research Institute
#            </a>
#           </li>
#           <li>
#            <a href="https://www.dhamma.org/en/global.htm" target="_blank">
#             Global Vipassana Pagoda
#            </a>
#           </li>
#           <li>
#            <a href="/en-US/about/mini_anapana">
#             Mini Anapana Meditation
#            </a>
#           </li>
#           <li>
#            <a href="/en-US/about/more_language_sites">
#             More Language Sites
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li id="nav-language">
#          <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#           <i class="glyphicon glyphicon-globe">
#           </i>
#           U.S. English
#          </a>
#          <ul class="dropdown-menu" id="select-language-list">
#           <li>
#            <a href="/bg/courses/search">
#             български
#            </a>
#           </li>
#           <li>
#            <a href="/cs/courses/search">
#             čeština
#            </a>
#           </li>
#           <li>
#            <a href="/de/courses/search">
#             Deutsch
#            </a>
#           </li>
#           <li>
#            <a href="/el/courses/search">
#             Ελληνικά
#            </a>
#           </li>
#           <li>
#            <a href="/en/courses/search">
#             English
#            </a>
#           </li>
#           <li>
#            <a href="/en-US/courses/search">
#             U.S. English
#            </a>
#           </li>
#           <li>
#            <a href="/es/courses/search">
#             Español
#            </a>
#           </li>
#           <li>
#            <a href="/fa/courses/search">
#             فارسی
#            </a>
#           </li>
#           <li>
#            <a href="/fi/courses/search">
#             Suomi
#            </a>
#           </li>
#           <li>
#            <a href="/fr/courses/search">
#             Français
#            </a>
#           </li>
#           <li>
#            <a href="/fr-CA/courses/search">
#             Français canadien
#            </a>
#           </li>
#           <li>
#            <a href="/gu/courses/search">
#             ગુજરાતી
#            </a>
#           </li>
#           <li>
#            <a href="/he/courses/search">
#             עברית
#            </a>
#           </li>
#           <li>
#            <a href="/hi/courses/search">
#             हिन्दी
#            </a>
#           </li>
#           <li>
#            <a href="/hu/courses/search">
#             Magyar
#            </a>
#           </li>
#           <li>
#            <a href="/id/courses/search">
#             Bahasa Indonesia
#            </a>
#           </li>
#           <li>
#            <a href="/it/courses/search">
#             Italiano
#            </a>
#           </li>
#           <li>
#            <a href="/it-CH/courses/search">
#             Svizzero Italiano
#            </a>
#           </li>
#           <li>
#            <a href="/ja/courses/search">
#             日本語
#            </a>
#           </li>
#           <li>
#            <a href="/km/courses/search">
#             ភាសាខ្មែរ
#            </a>
#           </li>
#           <li>
#            <a href="/ko/courses/search">
#             한국어
#            </a>
#           </li>
#           <li>
#            <a href="/lt/courses/search">
#             Lietuvių
#            </a>
#           </li>
#           <li>
#            <a href="/lv/courses/search">
#             Latviešu
#            </a>
#           </li>
#           <li>
#            <a href="/mk/courses/search">
#             македонски
#            </a>
#           </li>
#           <li>
#            <a href="/mr/courses/search">
#             मराठी
#            </a>
#           </li>
#           <li>
#            <a href="/ne/courses/search">
#             नेपाली
#            </a>
#           </li>
#           <li>
#            <a href="/nl/courses/search">
#             Nederlands
#            </a>
#           </li>
#           <li>
#            <a href="/pl/courses/search">
#             Polski
#            </a>
#           </li>
#           <li>
#            <a href="/pt/courses/search">
#             Português
#            </a>
#           </li>
#           <li>
#            <a href="/pt-BR/courses/search">
#             Português do Brasil
#            </a>
#           </li>
#           <li>
#            <a href="/ro/courses/search">
#             Română
#            </a>
#           </li>
#           <li>
#            <a href="/ru/courses/search">
#             русский
#            </a>
#           </li>
#           <li>
#            <a href="/si/courses/search">
#             සිංහල
#            </a>
#           </li>
#           <li>
#            <a href="/sr/courses/search">
#             Српски
#            </a>
#           </li>
#           <li>
#            <a href="/sv/courses/search">
#             Svenska
#            </a>
#           </li>
#           <li>
#            <a href="/ta/courses/search">
#             தமிழ்
#            </a>
#           </li>
#           <li>
#            <a href="/te/courses/search">
#             తెలుగు
#            </a>
#           </li>
#           <li>
#            <a href="/th/courses/search">
#             ไทย
#            </a>
#           </li>
#           <li>
#            <a href="/tr/courses/search">
#             Türkçe
#            </a>
#           </li>
#           <li>
#            <a href="/vi/courses/search">
#             Tiếng Việt
#            </a>
#           </li>
#           <li>
#            <a href="/zh-HANS/courses/search">
#             简体字
#            </a>
#           </li>
#           <li>
#            <a href="/zh-HANT/courses/search">
#             繁體字
#            </a>
#           </li>
#           <li>
#            <p>
#             Translations are in progress. Some pages may have a mix of your selected language and English.
#            </p>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </nav>
#   </div>
#   <div class="container" id="container">
#    <div id="content">
#     <section id="top">
#      <div id="header-container">
#       <header id="page-header">
#        <div class="hidden-xs">
#         <div class="text-right" id="header-left">
#          <h1>
#           Vipassana
#          </h1>
#          <p>
#           As taught by S.N. Goenka
#          </p>
#         </div>
#         <div id="wheel">
#          <img alt="Aniwheel" src="/assets/aniwheel-a87352d07ff79e922e5afbc8775f603b.gif"/>
#         </div>
#         <div class="text-left" id="header-right">
#          <h1>
#           Meditation
#          </h1>
#          <p>
#           in the tradition of Sayagyi U Ba Khin
#          </p>
#         </div>
#         <div class="clearfix">
#         </div>
#        </div>
#        <div class="visible-xs">
#         <div id="wheel">
#          <a href="/en-US/index">
#           <img src="/assets/aniwheel-a87352d07ff79e922e5afbc8775f603b.gif" width="100%"/>
#          </a>
#         </div>
#         <a href="/en-US/index">
#          <h1>
#           Vipassana Meditation
#          </h1>
#         </a>
#         <p class="subhead">
#          As taught by S.N. Goenka
#          <br/>
#          in the tradition of Sayagyi U Ba Khin
#         </p>
#        </div>
#       </header>
#      </div>
#      <div class="hidden-xs">
#       <ul class="nav nav-pills" id="navbar">
#        <li id="nav-home">
#         <a class="dropdown-toggle" data-original-title="Home" href="/en-US/index" title="">
#          <i class="glyphicon glyphicon-home">
#          </i>
#         </a>
#        </li>
#        <li class=" dropdown" id="nav-about">
#         <a class="dropdown-toggle" href="/en-US/about/vipassana">
#          About
#         </a>
#         <ul class="dropdown-menu" id="about-menu" style="left: -19px;">
#          <li>
#           <a href="/en-US/about/vipassana">
#            What is Vipassana?
#           </a>
#          </li>
#          <li>
#           <a href="/en-US/about/goenka">
#            Mr. S.N. Goenka
#           </a>
#          </li>
#          <li>
#           <a href="/en-US/about/art">
#            The Art of Living: Vipassana Meditation
#           </a>
#          </li>
#          <li>
#           <a href="/en-US/about/code">
#            The Code of Discipline
#           </a>
#          </li>
#          <li>
#           <a href="/en-US/about/qanda">
#            Questions &amp; Answers About the Technique of Vipassana Meditation
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="dropdown" id="nav-courses">
#         <a class="dropdown-toggle" href="/en-US/courses/search" rel="nofollow">
#          Courses
#         </a>
#         <ul class="dropdown-menu" id="courses-menu" style="left: -19px;">
#          <li>
#           <a href="/en-US/courses/search" rel="nofollow">
#            Search
#           </a>
#          </li>
#          <li class="dropdown">
#           <a href="/en-US/courses/glossary" rel="nofollow">
#            Glossary
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="dropdown" id="nav-locations">
#         <a href="/en-US/locations/directory" rel="nofollow">
#          Locations
#         </a>
#         <ul class="dropdown-menu" id="resources-menu" style="left: -19px;">
#          <li>
#           <a href="/en-US/locations/directory" rel="nofollow">
#            Worldwide Directory
#           </a>
#          </li>
#          <li class="dropdown">
#           <a href="/en-US/maps#001" rel="nofollow">
#            Maps
#           </a>
#          </li>
#          <li>
#           <a href="/en-US/locations/contacts" rel="nofollow">
#            Contacts
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="dropdown" id="nav-special-sites">
#         <a class="dropdown-toggle" href="#">
#          Special Sites
#         </a>
#         <ul class="dropdown-menu" id="special-sites-menu" style="left: -14.5px;">
#          <li>
#           <a href="/os/" target="_blank">
#            For Old Students
#           </a>
#          </li>
#          <li>
#           <a href="http://www.executive.dhamma.org/" target="_blank">
#            Vipassana for Executives
#           </a>
#          </li>
#          <li>
#           <a href="http://www.prison.dhamma.org/" target="_blank">
#            Vipassana for Prisons
#           </a>
#          </li>
#          <li>
#           <a href="http://www.children.dhamma.org/" target="_blank">
#            Children's Courses
#           </a>
#          </li>
#          <li>
#           <a href="https://www.dhamma.org/en/vri.htm" target="_blank">
#            Vipassana Research Institute
#           </a>
#          </li>
#          <li>
#           <a href="https://www.dhamma.org/en/global.htm" target="_blank">
#            Global Vipassana Pagoda
#           </a>
#          </li>
#          <li>
#           <a href="/en-US/about/mini_anapana">
#            Mini Anapana Meditation
#           </a>
#          </li>
#          <li>
#           <a href="/en-US/about/more_language_sites">
#            More Language Sites
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li id="nav-language">
#         <a href="#set-language">
#          <i class="glyphicon glyphicon-globe">
#          </i>
#          U.S. English
#         </a>
#         <div class="panel panel-default" id="select-language">
#          <div class="panel-body">
#           <h3>
#            Select Language
#           </h3>
#           <ul id="select-language-list">
#            <li>
#             <a href="/bg/courses/search">
#              български
#             </a>
#            </li>
#            <li>
#             <a href="/cs/courses/search">
#              čeština
#             </a>
#            </li>
#            <li>
#             <a href="/de/courses/search">
#              Deutsch
#             </a>
#            </li>
#            <li>
#             <a href="/el/courses/search">
#              Ελληνικά
#             </a>
#            </li>
#            <li>
#             <a href="/en/courses/search">
#              English
#             </a>
#            </li>
#            <li>
#             <a href="/en-US/courses/search">
#              U.S. English
#             </a>
#            </li>
#            <li>
#             <a href="/es/courses/search">
#              Español
#             </a>
#            </li>
#            <li>
#             <a href="/fa/courses/search">
#              فارسی
#             </a>
#            </li>
#            <li>
#             <a href="/fi/courses/search">
#              Suomi
#             </a>
#            </li>
#            <li>
#             <a href="/fr/courses/search">
#              Français
#             </a>
#            </li>
#            <li>
#             <a href="/fr-CA/courses/search">
#              Français canadien
#             </a>
#            </li>
#           </ul>
#           <ul>
#            <li>
#             <a href="/gu/courses/search">
#              ગુજરાતી
#             </a>
#            </li>
#            <li>
#             <a href="/he/courses/search">
#              עברית
#             </a>
#            </li>
#            <li>
#             <a href="/hi/courses/search">
#              हिन्दी
#             </a>
#            </li>
#            <li>
#             <a href="/hu/courses/search">
#              Magyar
#             </a>
#            </li>
#            <li>
#             <a href="/id/courses/search">
#              Bahasa Indonesia
#             </a>
#            </li>
#            <li>
#             <a href="/it/courses/search">
#              Italiano
#             </a>
#            </li>
#            <li>
#             <a href="/it-CH/courses/search">
#              Svizzero Italiano
#             </a>
#            </li>
#            <li>
#             <a href="/ja/courses/search">
#              日本語
#             </a>
#            </li>
#            <li>
#             <a href="/km/courses/search">
#              ភាសាខ្មែរ
#             </a>
#            </li>
#            <li>
#             <a href="/ko/courses/search">
#              한국어
#             </a>
#            </li>
#            <li>
#             <a href="/lt/courses/search">
#              Lietuvių
#             </a>
#            </li>
#           </ul>
#           <ul>
#            <li>
#             <a href="/lv/courses/search">
#              Latviešu
#             </a>
#            </li>
#            <li>
#             <a href="/mk/courses/search">
#              македонски
#             </a>
#            </li>
#            <li>
#             <a href="/mr/courses/search">
#              मराठी
#             </a>
#            </li>
#            <li>
#             <a href="/ne/courses/search">
#              नेपाली
#             </a>
#            </li>
#            <li>
#             <a href="/nl/courses/search">
#              Nederlands
#             </a>
#            </li>
#            <li>
#             <a href="/pl/courses/search">
#              Polski
#             </a>
#            </li>
#            <li>
#             <a href="/pt/courses/search">
#              Português
#             </a>
#            </li>
#            <li>
#             <a href="/pt-BR/courses/search">
#              Português do Brasil
#             </a>
#            </li>
#            <li>
#             <a href="/ro/courses/search">
#              Română
#             </a>
#            </li>
#            <li>
#             <a href="/ru/courses/search">
#              русский
#             </a>
#            </li>
#           </ul>
#           <ul>
#            <li>
#             <a href="/si/courses/search">
#              සිංහල
#             </a>
#            </li>
#            <li>
#             <a href="/sr/courses/search">
#              Српски
#             </a>
#            </li>
#            <li>
#             <a href="/sv/courses/search">
#              Svenska
#             </a>
#            </li>
#            <li>
#             <a href="/ta/courses/search">
#              தமிழ்
#             </a>
#            </li>
#            <li>
#             <a href="/te/courses/search">
#              తెలుగు
#             </a>
#            </li>
#            <li>
#             <a href="/th/courses/search">
#              ไทย
#             </a>
#            </li>
#            <li>
#             <a href="/tr/courses/search">
#              Türkçe
#             </a>
#            </li>
#            <li>
#             <a href="/vi/courses/search">
#              Tiếng Việt
#             </a>
#            </li>
#            <li>
#             <a href="/zh-HANS/courses/search">
#              简体字
#             </a>
#            </li>
#            <li>
#             <a href="/zh-HANT/courses/search">
#              繁體字
#             </a>
#            </li>
#           </ul>
#           <div class="clearfix">
#           </div>
#           <hr/>
#           <p>
#            Translations are in progress. Some pages may have a mix of your selected language and English.
#           </p>
#           <br/>
#          </div>
#         </div>
#        </li>
#       </ul>
#      </div>
#     </section>
#     <section id="main">
#      <br/>
#      <section class="tabbed-header">
#       <h2>
#        Courses
#        <small class="icon hidden-xs">
#         <a data-content='&lt;span class="notes-title"&gt;To find a course:&lt;/span&gt; &amp;nbsp;&amp;nbsp;&amp;nbsp; 1. (Optional) Enter one or more search criteria in the boxes &amp;nbsp;&amp;nbsp;&amp;nbsp; 2. Click the blue search button.&lt;br /&gt;
# &lt;br type="_moz" /&gt;&lt;hr /&gt;&lt;div&gt;
# 	How to locate and apply for courses:  &lt;/div&gt;
# &lt;div&gt;
# 	&lt;ul&gt;
# 		&lt;li&gt;
# 			Select an applicable tab, refine the search options by specifying one or more values per box (re-click the same box to specify additional values) and press the search button&lt;/li&gt;
# 		&lt;li&gt;
# 			Find a suitable course from the list of available courses and click the Apply button to access the online application form in the language of your choice (only the top 100 results are returned; if you do not find a suitable course from the returned result set then refine the search options further and reissue the search)&lt;/li&gt;
# 		&lt;li&gt;
# 			Read carefully the Introduction to the Technique and Code of Discipline which you will be asked to follow during your course.  Fully and completely fill out all the sections of application form and submit it.  An application is required to register for all courses.&lt;/li&gt;
# 		&lt;li&gt;
# 			Await notification.  All correspondence will be through e-mail if you give an e-mail address in your application. Due to the large volume of applications, it may take several weeks before receiving notification.&lt;/li&gt;
# 		&lt;li&gt;
# 			If your application is accepted then we require you to confirm you will be attending in order to secure your place in the course.&lt;/li&gt;
# 	&lt;/ul&gt;
# &lt;/div&gt;' data-html="true" data-original-title="" data-placement="left" data-toggle="popover" href="#" title="">
#          <i class="glyphicon glyphicon-question-sign">
#          </i>
#         </a>
#        </small>
#       </h2>
#       <div id="course-search">
#        <ul class="hidden-xs nav nav-tabs nav-quarters" id="student-type-select">
#         <li class="active" data-bind="css: {active: current_state() == 'NewStudents'}, click: search_new_students">
#          <a class="new-student" href="#">
#           For New Students
#          </a>
#         </li>
#         <li class="" data-bind="css: {active: current_state() == 'OldStudents'}, click: search_old_students">
#          <a class="old-student" href="#">
#           For Old Students
#          </a>
#         </li>
#         <li class="" data-bind="css: {active: current_state() == 'Children'}, click: search_children">
#          <a class="child" href="#">
#           For Children/Teens
#          </a>
#         </li>
#         <li class="" data-bind="css: {active: current_state() == 'Executives'}, click: search_executives">
#          <a class="executive" href="#">
#           For Executives
#          </a>
#         </li>
#        </ul>
#        <div class="search-panel" id="course-search-panel">
#         <div id="search-panel-form">
#          <div class="row">
#           <div class="col-sm-10" id="search-panel-form-inputs">
#            <div class="row">
#             <div class="col-sm-4 visible-xs form-group">
#              <select class="form-control" data-bind="event: { change: change_search_mode }" id="student-type-select-mobile">
#               <option value="NewStudents">
#                For New Students
#               </option>
#               <option value="OldStudents">
#                For Old Students
#               </option>
#               <option value="Children">
#                For Children/Teens
#               </option>
#               <option value="Executives">
#                For Executives
#               </option>
#              </select>
#             </div>
#             <div class="col-sm-4 form-group" data-bind="css: {'has-error': dates_invalid}">
#              <input class="form-control date" data-bind="daterangepicker: {separator: ' \u2014 ', arrows: true, showDropdowns: true,
#           format: date_format(), locale: { applyLabel: 'Confirm',
#           cancelLabel: 'Cancel', fromLabel: 'from',
#           toLabel: 'to' }}, value: search_daterange" id="course-search-date-range" placeholder="Select Date Range"/>
#             </div>
#             <div class="col-sm-4">
#              <div class="form-group">
#               <div class="select2-container select2-container-multi form-control" id="s2id_loc_search">
#                <ul class="select2-choices">
#                 <li class="select2-search-field">
#                  <label class="select2-offscreen" for="s2id_autogen1">
#                  </label>
#                  <input autocapitalize="off" autocomplete="off" autocorrect="off" class="select2-input select2-default" id="s2id_autogen1" placeholder="" spellcheck="false" style="width: 222px;" type="text"/>
#                 </li>
#                </ul>
#                <div class="select2-drop select2-drop-multi select2-display-none">
#                 <ul class="select2-results">
#                  <li class="select2-no-results">
#                   No matches found
#                  </li>
#                  <li class="select2-no-results">
#                   No matches found
#                  </li>
#                  <li class="select2-no-results">
#                   No matches found
#                  </li>
#                 </ul>
#                </div>
#               </div>
#               <input class="form-control" data-bind="select2ValueUpdate: search_region, select2: select2_config_region()" id="loc_search" placeholder="State/Province, Country, Region" style="display: none;" tabindex="-1" type="hidden" value=""/>
#              </div>
#             </div>
#             <div class="col-sm-4">
#              <div class="select2-container select2-container-multi form-control" id="s2id_language-filter">
#               <ul class="select2-choices">
#                <li class="select2-search-field">
#                 <label class="select2-offscreen" for="s2id_autogen2">
#                 </label>
#                 <input autocapitalize="off" autocomplete="off" autocorrect="off" class="select2-input select2-default" id="s2id_autogen2" placeholder="" spellcheck="false" style="width: 222px;" type="text"/>
#                </li>
#               </ul>
#               <div class="select2-drop select2-drop-multi select2-display-none">
#                <ul class="select2-results">
#                 <li class="select2-no-results">
#                  No matches found
#                 </li>
#                 <li class="select2-no-results">
#                  No matches found
#                 </li>
#                </ul>
#               </div>
#              </div>
#              <select class="form-control" data-bind="select2: {placeholder: 'Select Course Language'}, options: instruction_languages, optionsText: 'description', optionsValue: 'iso_code', selectedOptions: search_languages" id="language-filter" multiple="" style="display: none;" tabindex="-1">
#               <option value="af">
#                Afrikaans
#               </option>
#               <option value="am">
#                Amharic
#               </option>
#               <option value="ar">
#                Arabic
#               </option>
#               <option value="bn">
#                Bengali
#               </option>
#               <option value="bg">
#                Bulgarian
#               </option>
#               <option value="my">
#                Burmese
#               </option>
#               <option value="yue">
#                Cantonese
#               </option>
#               <option value="cs">
#                Czech
#               </option>
#               <option value="da">
#                Danish
#               </option>
#               <option value="nl">
#                Dutch
#               </option>
#               <option value="en">
#                English
#               </option>
#               <option value="fi">
#                Finnish
#               </option>
#               <option value="fr">
#                French
#               </option>
#               <option value="de">
#                German
#               </option>
#               <option value="el">
#                Greek
#               </option>
#               <option value="gu">
#                Gujarati
#               </option>
#               <option value="hak">
#                Hakka
#               </option>
#               <option value="he">
#                Hebrew
#               </option>
#               <option value="hi">
#                Hindi
#               </option>
#               <option value="hu">
#                Hungarian
#               </option>
#               <option value="id">
#                Indonesian
#               </option>
#               <option value="it">
#                Italian
#               </option>
#               <option value="ja">
#                Japanese
#               </option>
#               <option value="kn">
#                Kannada
#               </option>
#               <option value="km">
#                Khmer
#               </option>
#               <option value="ko">
#                Korean
#               </option>
#               <option value="lv">
#                Latvian
#               </option>
#               <option value="lt">
#                Lithuanian
#               </option>
#               <option value="ml">
#                Malayalam
#               </option>
#               <option value="cmn">
#                Mandarin
#               </option>
#               <option value="mr">
#                Marathi
#               </option>
#               <option value="mon">
#                Mon
#               </option>
#               <option value="mn">
#                Mongolian
#               </option>
#               <option value="ne">
#                Nepali
#               </option>
#               <option value="new">
#                Newari
#               </option>
#               <option value="no">
#                Norwegian
#               </option>
#               <option value="fa">
#                Persian (Farsi)
#               </option>
#               <option value="pl">
#                Polish
#               </option>
#               <option value="pt">
#                Portuguese
#               </option>
#               <option value="pa">
#                Punjabi
#               </option>
#               <option value="ro">
#                Romanian
#               </option>
#               <option value="ru">
#                Russian
#               </option>
#               <option value="sr">
#                Serbian
#               </option>
#               <option value="hbs">
#                Serbo-Croatian
#               </option>
#               <option value="shn">
#                Shan
#               </option>
#               <option value="si">
#                Sinhala
#               </option>
#               <option value="sl">
#                Slovenian
#               </option>
#               <option value="es">
#                Spanish
#               </option>
#               <option value="sw">
#                Swahili
#               </option>
#               <option value="sv">
#                Swedish
#               </option>
#               <option value="tl">
#                Tagalog
#               </option>
#               <option value="ta">
#                Tamil
#               </option>
#               <option value="te">
#                Telugu
#               </option>
#               <option value="th">
#                Thai
#               </option>
#               <option value="tr">
#                Turkish
#               </option>
#               <option value="vi">
#                Vietnamese
#               </option>
#              </select>
#             </div>
#            </div>
#            <div class="row">
#             <!-- ko if: showAdvancedOptions -->
#             <!-- /ko -->
#             <!-- ko if: current_state() == 'OldStudents' -->
#             <!-- /ko -->
#             <div class="col-sm-4">
#             </div>
#            </div>
#           </div>
#           <div class="col-sm-2">
#            <a class="btn btn-apply center" data-bind="click: performSearch" href="/search" style="width:100%;">
#             <i class="glyphicon glyphicon-search">
#             </i>
#            </a>
#            <!-- ko if: share() -->
#            <!-- /ko -->
#           </div>
#          </div>
#         </div>
#         <div class="search-toolbar btn-toolbar" id="course-list-setting">
#          <!-- ko if: results_on_search -->
#          <!-- /ko -->
#         </div>
#        </div>
#       </div>
#      </section>
#      <section data-bind="template: current_view" id="course-search-results">
#       <!-- Template for rendering list of results -->
#       <!-- ko foreach: {data: courses, afterRender: postprocess_course} -->
#       <!-- /ko -->
#      </section>
#      <!-- ko if: results_on_search -->
#      <!-- /ko -->
#      <!-- ko if: searched -->
#      <!-- /ko -->
#      <div id="course-search-instructions">
#       <!-- ko if: current_state() == 'NewStudents' -->
#       <p>
#        <a name="10-Day">
#        </a>
#        <span class="notes-title">
#         10-day Courses
#        </span>
#        are an introductory course to Vipassana Meditation where the technique is taught step-by-step each day. The courses begin after a 2 - 4 pm registration period and orientation, followed by 10 full days of meditation, and end the morning of the 11th day by 7:30 am.
#       </p>
#       <!-- /ko -->
#       <!-- ko if: current_state() == 'OldStudents' -->
#       <!-- /ko -->
#       <!-- ko if: current_state() == 'Children' -->
#       <!-- /ko -->
#       <!-- ko if: current_state() == 'Executives' -->
#       <!-- /ko -->
#      </div>
#      <script id="course_status" type="text/html">
#       &lt;div data-bind="foreach: status"&gt;
# &lt;span data-bind="html: status_text, classes: status_classes"&gt;&lt;/span&gt;
# &lt;/div&gt;
#      </script>
#      <div id="location-modal-container">
#      </div>
#     </section>
#    </div>
#    <div id="footer">
#     <hr/>
#     <p>
#      Dhamma.org
#     </p>
#     <p>
#      <a href="/en-US/about/privacy">
#       Privacy Policy
#      </a>
#      |
#      <a href="mailto:webmaster@dhamma.org">
#       Email Webmaster
#      </a>
#     </p>
#     <p>
#      <a href="https://itunes.apple.com/us/app/dhamma-org/id1127952631?mt=8">
#       <img alt="App store us uk" src="/assets/app-store-us-uk-475b9d8be87e34a116c3763a3640c26f.svg" width="135"/>
#      </a>
#      <a href="https://play.google.com/store/apps/details?id=org.dhamma">
#       <img alt="Play store badge" src="/assets/play-store-badge-fd9ac7cfac52af3d94574d52ae0f29d9.png" width="155"/>
#      </a>
#     </p>
#     <p>
#      <a href="/en-US/about/mobile-app">
#       Dhamma.org Mobile App
#      </a>
#     </p>
#    </div>
#   </div>
#   <script src="/assets/application-bd78d5e3413c14cb87460a1c58872ab0.js" type="text/javascript">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/select2/3.5.2/select2.min.js" type="text/javascript">
#   </script>
#   <img alt="Spinner" class="hidden" src="/assets/spinner-88b380ce4d66f6d126304c5acda1da57.gif"/>
#   <script type="text/javascript">
#    $(document).ajaxStart(function() {
#         $.blockUI({
# message: '&lt;div id="block-spinner"&gt;&lt;/div&gt;',
#           css: {
#             color: '#029',
#             left: 0,
#             border: 0,
#             backgroundColor: 'transparent',
#             width: '100%',
#             height: '100px',
#           },
#           baseZ: 10000
#           });
#       }).ajaxStop($.unblockUI);
#   </script>
#   <script type="text/javascript">
#    $(function() {
#
#       });
#   </script>
#   <script type="text/javascript">
#    $(".listOfCountriesNotYet").popover({
#       content: ""
#     });
#   </script>
#   <script id="list" type="text/html">
#    &lt;!-- Template for rendering list of results --&gt;
# &lt;!-- ko foreach: {data: courses, afterRender: postprocess_course} --&gt;
# &lt;div class="visible-xs course"&gt;
#   &lt;div class="row"&gt;
#     &lt;div class="col-xs-2"&gt;
#       &lt;div data-bind="with: location"&gt;
#         &lt;div class="flag" data-bind="css: flag_icon_class" width=35 height=35&gt;&lt;/div&gt;
#       &lt;/div&gt;
#     &lt;/div&gt;
#     &lt;div class="col-xs-10"&gt;
#       &lt;h3&gt;
#         &lt;span class="date" data-bind="html: localizedStartDate"&gt;&lt;/span&gt;
#         &lt;!-- ko if: course_end_date != null --&gt;
#         -
#         &lt;span class="date" data-bind="html: localizedEndDate"&gt;&lt;/span&gt;
#         &lt;!-- /ko --&gt;
#       &lt;/h3&gt;
#       &lt;div class="course-location" data-bind="with: location"&gt;
#         &lt;h4 class="course-location-title"&gt;
#           &lt;!-- ko if: dhamma_name() --&gt;
#             &lt;!-- ko if: $root.show_center_links() --&gt;
#             &lt;a href="##" data-toggle="dropdown" data-bind="text: dhamma_name"&gt;&lt;/a&gt;,
#             &lt;!-- /ko --&gt;
#             &lt;!-- ko if: !$root.show_center_links() --&gt;
#             &lt;span data-bind="text: dhamma_name"&gt;&lt;/span&gt;,
#             &lt;!-- /ko --&gt;
#           &lt;!-- /ko --&gt;
#           &lt;!-- ko if: $root.show_center_links() --&gt;
#           &lt;ul class="dropdown-menu"&gt;
#             &lt;!-- ko if: location_languages().length &gt; 1 --&gt;
#             &lt;!-- ko foreach: location_languages() --&gt;
#             &lt;li&gt;
#               &lt;a target="_blank" href="#" data-bind="attr:{href:schedule_url}"&gt;&lt;i class="glyphicon glyphicon-calendar" /&gt; Courses (&lt;span data-bind="text: description"&gt;&lt;/span&gt;)&lt;/a&gt;
#             &lt;/li&gt;
#             &lt;!-- /ko --&gt;
#             &lt;!-- /ko --&gt;
#             &lt;!-- ko if: location_languages().length == 1 --&gt;
#               &lt;!-- ko with: location_languages()[0] --&gt;
#               &lt;li&gt;&lt;a href="#" data-bind="attr:{href:schedule_url}" target="_blank"&gt;&lt;i class="glyphicon glyphicon-calendar" /&gt; Courses&lt;/a&gt;&lt;/li&gt;
#               &lt;!-- /ko --&gt;
#             &lt;!-- /ko --&gt;
#             &lt;li&gt;&lt;a target="_blank" data-bind="attr: {href: website_url}"&gt;&lt;i class="glyphicon glyphicon-home" /&gt; Website&lt;/a&gt;&lt;/li&gt;
#             &lt;!-- ko if: $root.show_map_link() --&gt;
#             &lt;li&gt;&lt;a target="_blank" data-bind="css:{disabled: !(map_url() != null &amp;&amp; map_url().length &gt; 0)}, attr: {href: map_url}"&gt;&lt;i class="glyphicon glyphicon-map-marker" /&gt; Map&lt;/a&gt;&lt;/li&gt;
#             &lt;!-- /ko --&gt;
#           &lt;/ul&gt;
#           &lt;!-- /ko --&gt;
#           &lt;!-- ko if: sub_location() != null &amp;&amp; sub_location_url() != null --&gt;
#             &lt;a target="_blank" data-bind="attr: {href: sub_location_url}, text: sub_location"&gt;&lt;/a&gt;
#           &lt;!-- /ko --&gt;
#           &lt;!-- ko if: sub_location() != null &amp;&amp; sub_location_url() == null --&gt;
#             &lt;span data-bind="text: sub_location"&gt;&lt;/span&gt;
#           &lt;!-- /ko --&gt;
#           &lt;!-- ko if: sub_location() == null --&gt;
#             &lt;span data-bind="text: city_province_country"&gt;&lt;/span&gt;
#           &lt;!-- /ko --&gt;
#           &lt;span data-bind="css: pin_class"&gt;&lt;/span&gt;
#         &lt;/h4&gt;
#         &lt;!-- /ko --&gt;
#       &lt;/div&gt;
#       &lt;h4&gt;
#         &lt;span class="info"&gt;&lt;span data-bind="html: course_type"&gt;&lt;/span&gt;&lt;/span&gt;
#         &lt;!-- ko if: haveCourseInstructionLanguages --&gt;
#           &amp;nbsp;&amp;nbsp;
#           &lt;!-- ko if: course_instruction_languages().length &gt; 1 --&gt;
#           &lt;span class="info course-languages" href="##" data-bind="foreach: course_instruction_languages"&gt;
#             &lt;span data-bind="text: $data"&gt;&lt;/span&gt;
#           &lt;/span&gt;
#           &lt;!-- /ko --&gt;
#           &lt;!-- ko if: course_instruction_languages().length == 1 --&gt;
#           &lt;span class="info course-languages" data-html="true" data-bind="foreach: course_instruction_languages"&gt;
#             &lt;span data-bind="text: $data"&gt;&lt;/span&gt;
#           &lt;/span&gt;
#           &lt;!-- /ko --&gt;
#         &lt;!-- /ko --&gt;
#       &lt;/h4&gt;
#       &lt;h4 class="info" data-bind="template: 'course_status'"&gt;&lt;/h4&gt;
#     &lt;/div&gt;
#   &lt;/div&gt;
#   &lt;div data-bind="if: canApply"&gt;
#   &lt;!-- ko if: hasManyApplyLanguages --&gt;
#   &lt;div class="btn-group btn-group-apply"&gt;
#     &lt;button type="button" class="btn btn-apply dropdown-toggle" data-toggle="dropdown"&gt;
#       Apply &lt;span class="caret caret-white"&gt;&lt;/span&gt;
#     &lt;/button&gt;
#     &lt;ul class="dropdown-menu" role="menu" data-bind="foreach: apply_languages"&gt;
#       &lt;li&gt;
#         &lt;a href="#" target="_blank" data-bind="text: description_with_indicator, attr:{href:apply_link_url}, click: handle_apply_click"&gt;&lt;/a&gt;
#       &lt;/li&gt;
#     &lt;/ul&gt;
#   &lt;/div&gt;
#   &lt;!-- /ko --&gt;
#   &lt;!-- ko ifnot: hasManyApplyLanguages --&gt;
#     &lt;!-- ko foreach: apply_languages  --&gt;
#     &lt;a class="btn btn-apply" target="_blank" data-bind="attr: {href:apply_link_url}, click: handle_apply_click"&gt;
#       Apply&lt;span data-bind="visible: apply_override"&gt;*&lt;/span&gt;
#     &lt;/a&gt;
#     &lt;!-- /ko --&gt;
#   &lt;!-- /ko --&gt;
# &lt;/div&gt;
#
# &lt;/div&gt;
# &lt;div class="hidden-xs list-item course row"&gt;
#   &lt;div class="col-sm-2 col-apply"&gt;
#     &lt;h3&gt;&lt;/h3&gt;
#     &lt;div data-bind="if: canApply"&gt;
#   &lt;!-- ko if: hasManyApplyLanguages --&gt;
#   &lt;div class="btn-group btn-group-apply"&gt;
#     &lt;button type="button" class="btn btn-apply dropdown-toggle" data-toggle="dropdown"&gt;
#       Apply &lt;span class="caret caret-white"&gt;&lt;/span&gt;
#     &lt;/button&gt;
#     &lt;ul class="dropdown-menu" role="menu" data-bind="foreach: apply_languages"&gt;
#       &lt;li&gt;
#         &lt;a href="#" target="_blank" data-bind="text: description_with_indicator, attr:{href:apply_link_url}, click: handle_apply_click"&gt;&lt;/a&gt;
#       &lt;/li&gt;
#     &lt;/ul&gt;
#   &lt;/div&gt;
#   &lt;!-- /ko --&gt;
#   &lt;!-- ko ifnot: hasManyApplyLanguages --&gt;
#     &lt;!-- ko foreach: apply_languages  --&gt;
#     &lt;a class="btn btn-apply" target="_blank" data-bind="attr: {href:apply_link_url}, click: handle_apply_click"&gt;
#       Apply&lt;span data-bind="visible: apply_override"&gt;*&lt;/span&gt;
#     &lt;/a&gt;
#     &lt;!-- /ko --&gt;
#   &lt;!-- /ko --&gt;
# &lt;/div&gt;
#
#   &lt;/div&gt;
#   &lt;div class="col-sm-3"&gt;
#     &lt;div class="course-info"&gt;
#       &lt;h3&gt;
#         &lt;span class="date" data-bind="html: localizedStartDate"&gt;&lt;/span&gt;
#         &lt;!-- ko if: course_end_date != null --&gt;
#         -
#         &lt;span class="date" data-bind="html: localizedEndDate"&gt;&lt;/span&gt;
#         &lt;!-- /ko --&gt;
#       &lt;/h3&gt;
#       &lt;h4&gt;
#         &lt;a class="info" data-placement="bottom" data-toggle="tooltip" href="##" data-html="true" data-bind="attr: {title: course_type_hint}"&gt;&lt;span data-bind="html: course_type"&gt;&lt;/span&gt;&lt;/a&gt;
#         &lt;!-- ko if: haveCourseInstructionLanguages --&gt;
#           &lt;br /&gt;
#           &lt;!-- ko if: course_instruction_languages().length &gt; 1 --&gt;
#           &lt;a class="info course-languages" href="##" data-html="true" data-toggle="tooltip" data-placement="bottom" data-bind="attr: {title: instruction_languages_tooltip}, foreach: course_instruction_languages"&gt;
#             &lt;span data-bind="text: $data"&gt;&lt;/span&gt;
#           &lt;/a&gt;
#           &lt;!-- /ko --&gt;
#           &lt;!-- ko if: course_instruction_languages().length == 1 --&gt;
#           &lt;span class="info course-languages" data-html="true" data-toggle="tooltip" data-placement="bottom" data-bind="attr: {title: instruction_languages_tooltip}, foreach: course_instruction_languages"&gt;
#             &lt;span data-bind="text: $data"&gt;&lt;/span&gt;
#           &lt;/span&gt;
#           &lt;!-- /ko --&gt;
#         &lt;!-- /ko --&gt;
#       &lt;/h4&gt;
#       &lt;h4 class="info" data-bind="template: 'course_status'"&gt;&lt;/h4&gt;
#     &lt;/div&gt;
#   &lt;/div&gt;
#   &lt;div class="col-sm-4"&gt;
#     &lt;div class="course-location" data-bind="with: location"&gt;
#       &lt;div class="flag pull-left" data-bind="css: flag_icon_class" width=35 height=35&gt;&lt;/div&gt;
#       &lt;div class="course-location-meta"&gt;
#         &lt;div class="course-location-title"&gt;
#           &lt;!-- ko if: sub_location() != null &amp;&amp; sub_location_url() != null --&gt;
#             &lt;a target="_blank" data-bind="attr: {href: sub_location_url}, text: sub_location"&gt;&lt;/a&gt;
#           &lt;!-- /ko --&gt;
#           &lt;!-- ko if: sub_location() != null &amp;&amp; sub_location_url() == null --&gt;
#             &lt;span data-bind="text: sub_location"&gt;&lt;/span&gt;
#           &lt;!-- /ko --&gt;
#           &lt;!-- ko if: sub_location() == null --&gt;
#             &lt;span data-bind="text: city_province_country"&gt;&lt;/span&gt;
#           &lt;!-- /ko --&gt;
#           &lt;span data-bind="css: pin_class"&gt;&lt;/span&gt;
#         &lt;/div&gt;
#         &lt;!-- ko if: dhamma_name() --&gt;
#           &lt;!-- ko if: $root.show_center_links() --&gt;
#           &lt;a class="underline location-link" target="_blank" href="##"
#             data-toggle="modal" data-bind="text: dhamma_name, attr: { 'data-id':
# ...
#           </i>
#          </th>
#          <th colspan="5" style="width: auto">
#           <select class="monthselect">
#            <option value="0">
#             Jan
#            </option>
#            <option value="1">
#             Feb
#            </option>
#            <option value="2">
#             Mar
#            </option>
#            <option value="3">
#             Apr
#            </option>
#            <option value="4">
#             May
#            </option>
#            <option value="5">
#             Jun
#            </option>
#            <option value="6">
#             Jul
#            </option>
#            <option value="7">
#             Aug
#            </option>
#            <option value="8">
#             Sep
#            </option>
#            <option value="9">
#             Oct
#            </option>
#            <option selected="selected" value="10">
#             Nov
#            </option>
#            <option value="11">
#             Dec
#            </option>
#           </select>
#           <select class="yearselect">
#            <option value="1968">
#             1968
#            </option>
#            <option value="1969">
#             1969
#            </option>
#            <option value="1970">
#             1970
#            </option>
#            <option value="1971">
#             1971
#            </option>
#            <option value="1972">
#             1972
#            </option>
#            <option value="1973">
#             1973
#            </option>
#            <option value="1974">
#             1974
#            </option>
#            <option value="1975">
#             1975
#            </option>
#            <option value="1976">
#             1976
#            </option>
#            <option value="1977">
#             1977
#            </option>
#            <option value="1978">
#             1978
#            </option>
#            <option value="1979">
#             1979
#            </option>
#            <option value="1980">
#             1980
#            </option>
#            <option value="1981">
#             1981
#            </option>
#            <option value="1982">
#             1982
#            </option>
#            <option value="1983">
#             1983
#            </option>
#            <option value="1984">
#             1984
#            </option>
#            <option value="1985">
#             1985
#            </option>
#            <option value="1986">
#             1986
#            </option>
#            <option value="1987">
#             1987
#            </option>
#            <option value="1988">
#             1988
#            </option>
#            <option value="1989">
#             1989
#            </option>
#            <option value="1990">
#             1990
#            </option>
#            <option value="1991">
#             1991
#            </option>
#            <option value="1992">
#             1992
#            </option>
#            <option value="1993">
#             1993
#            </option>
#            <option value="1994">
#             1994
#            </option>
#            <option value="1995">
#             1995
#            </option>
#            <option value="1996">
#             1996
#            </option>
#            <option value="1997">
#             1997
#            </option>
#            <option value="1998">
#             1998
#            </option>
#            <option value="1999">
#             1999
#            </option>
#            <option value="2000">
#             2000
#            </option>
#            <option value="2001">
#             2001
#            </option>
#            <option value="2002">
#             2002
#            </option>
#            <option value="2003">
#             2003
#            </option>
#            <option value="2004">
#             2004
#            </option>
#            <option value="2005">
#             2005
#            </option>
#            <option value="2006">
#             2006
#            </option>
#            <option value="2007">
#             2007
#            </option>
#            <option value="2008">
#             2008
#            </option>
#            <option value="2009">
#             2009
#            </option>
#            <option value="2010">
#             2010
#            </option>
#            <option value="2011">
#             2011
#            </option>
#            <option value="2012">
#             2012
#            </option>
#            <option value="2013">
#             2013
#            </option>
#            <option value="2014">
#             2014
#            </option>
#            <option value="2015">
#             2015
#            </option>
#            <option value="2016">
#             2016
#            </option>
#            <option value="2017">
#             2017
#            </option>
#            <option selected="selected" value="2018">
#             2018
#            </option>
#            <option value="2019">
#             2019
#            </option>
#            <option value="2020">
#             2020
#            </option>
#            <option value="2021">
#             2021
#            </option>
#            <option value="2022">
#             2022
#            </option>
#            <option value="2023">
#             2023
#            </option>
#           </select>
#          </th>
#          <th class="next available">
#           <i class="icon-arrow-right glyphicon glyphicon-arrow-right">
#           </i>
#          </th>
#         </tr>
#         <tr>
#          <th>
#           Su
#          </th>
#          <th>
#           Mo
#          </th>
#          <th>
#           Tu
#          </th>
#          <th>
#           We
#          </th>
#          <th>
#           Th
#          </th>
#          <th>
#           Fr
#          </th>
#          <th>
#           Sa
#          </th>
#         </tr>
#        </thead>
#        <tbody>
#         <tr>
#          <td class="available off" data-title="r0c0">
#           28
#          </td>
#          <td class="available off" data-title="r0c1">
#           29
#          </td>
#          <td class="available off" data-title="r0c2">
#           30
#          </td>
#          <td class="available off" data-title="r0c3">
#           31
#          </td>
#          <td class="available" data-title="r0c4">
#           1
#          </td>
#          <td class="available" data-title="r0c5">
#           2
#          </td>
#          <td class="available" data-title="r0c6">
#           3
#          </td>
#         </tr>
#         <tr>
#          <td class="available" data-title="r1c0">
#           4
#          </td>
#          <td class="available" data-title="r1c1">
#           5
#          </td>
#          <td class="available" data-title="r1c2">
#           6
#          </td>
#          <td class="available" data-title="r1c3">
#           7
#          </td>
#          <td class="available" data-title="r1c4">
#           8
#          </td>
#          <td class="available" data-title="r1c5">
#           9
#          </td>
#          <td class="available" data-title="r1c6">
#           10
#          </td>
#         </tr>
#         <tr>
#          <td class="available" data-title="r2c0">
#           11
#          </td>
#          <td class="available" data-title="r2c1">
#           12
#          </td>
#          <td class="available" data-title="r2c2">
#           13
#          </td>
#          <td class="available active start-date" data-title="r2c3">
#           14
#          </td>
#          <td class="available in-range" data-title="r2c4">
#           15
#          </td>
#          <td class="available in-range" data-title="r2c5">
#           16
#          </td>
#          <td class="available in-range" data-title="r2c6">
#           17
#          </td>
#         </tr>
#         <tr>
#          <td class="available in-range" data-title="r3c0">
#           18
#          </td>
#          <td class="available in-range" data-title="r3c1">
#           19
#          </td>
#          <td class="available in-range" data-title="r3c2">
#           20
#          </td>
#          <td class="available in-range" data-title="r3c3">
#           21
#          </td>
#          <td class="available in-range" data-title="r3c4">
#           22
#          </td>
#          <td class="available in-range" data-title="r3c5">
#           23
#          </td>
#          <td class="available in-range" data-title="r3c6">
#           24
#          </td>
#         </tr>
#         <tr>
#          <td class="available in-range" data-title="r4c0">
#           25
#          </td>
#          <td class="available in-range" data-title="r4c1">
#           26
#          </td>
#          <td class="available in-range" data-title="r4c2">
#           27
#          </td>
#          <td class="available in-range" data-title="r4c3">
#           28
#          </td>
#          <td class="available in-range" data-title="r4c4">
#           29
#          </td>
#          <td class="available in-range" data-title="r4c5">
#           30
#          </td>
#          <td class="available off in-range" data-title="r4c6">
#           1
#          </td>
#         </tr>
#         <tr>
#          <td class="available off in-range" data-title="r5c0">
#           2
#          </td>
#          <td class="available off in-range" data-title="r5c1">
#           3
#          </td>
#          <td class="available off in-range" data-title="r5c2">
#           4
#          </td>
#          <td class="available off in-range" data-title="r5c3">
#           5
#          </td>
#          <td class="available off in-range" data-title="r5c4">
#           6
#          </td>
#          <td class="available off in-range" data-title="r5c5">
#           7
#          </td>
#          <td class="available off in-range" data-title="r5c6">
#           8
#          </td>
#         </tr>
#        </tbody>
#       </table>
#      </div>
#     </div>
#    </div>
#    <div class="calendar-container right">
#     <div class="daterangepicker_end_input">
#      <label for="daterangepicker_end">
#       to
#      </label>
#      <input class="form-control input-mini" disabled="" name="daterangepicker_end" style="text-align:center;" type="text" value=""/>
#     </div>
#     <div class="calendar right" style="display: block;">
#      <div class="calendar-date">
#       <table class="table-condensed">
#        <thead>
#         <tr>
#          <th class="prev available">
#           <i class="icon-arrow-left glyphicon glyphicon-arrow-left">
#           </i>
#          </th>
#          <th colspan="5" style="width: auto">
#           <select class="monthselect">
#            <option value="0">
#             Jan
#            </option>
#            <option value="1">
#             Feb
#            </option>
#            <option value="2">
#             Mar
#            </option>
#            <option value="3">
#             Apr
#            </option>
#            <option value="4">
#             May
#            </option>
#            <option value="5">
#             Jun
#            </option>
#            <option value="6">
#             Jul
#            </option>
#            <option value="7">
#             Aug
#            </option>
#            <option value="8">
#             Sep
#            </option>
#            <option value="9">
#             Oct
#            </option>
#            <option selected="selected" value="10">
#             Nov
#            </option>
#            <option value="11">
#             Dec
#            </option>
#           </select>
#           <select class="yearselect">
#            <option value="2018">
#             2018
#            </option>
#            <option selected="selected" value="2019">
#             2019
#            </option>
#            <option value="2020">
#             2020
#            </option>
#            <option value="2021">
#             2021
#            </option>
#            <option value="2022">
#             2022
#            </option>
#            <option value="2023">
#             2023
#            </option>
#            <option value="2024">
#             2024
#            </option>
#           </select>
#          </th>
#          <th class="next available">
#           <i class="icon-arrow-right glyphicon glyphicon-arrow-right">
#           </i>
#          </th>
#         </tr>
#         <tr>
#          <th>
#           Su
#          </th>
#          <th>
#           Mo
#          </th>
#          <th>
#           Tu
#          </th>
#          <th>
#           We
#          </th>
#          <th>
#           Th
#          </th>
#          <th>
#           Fr
#          </th>
#          <th>
#           Sa
#          </th>
#         </tr>
#        </thead>
#        <tbody>
#         <tr>
#          <td class="available off in-range" data-title="r0c0">
#           27
#          </td>
#          <td class="available off in-range" data-title="r0c1">
#           28
#          </td>
#          <td class="available off in-range" data-title="r0c2">
#           29
#          </td>
#          <td class="available off in-range" data-title="r0c3">
#           30
#          </td>
#          <td class="available off in-range" data-title="r0c4">
#           31
#          </td>
#          <td class="available in-range" data-title="r0c5">
#           1
#          </td>
#          <td class="available in-range" data-title="r0c6">
#           2
#          </td>
#         </tr>
#         <tr>
#          <td class="available in-range" data-title="r1c0">
#           3
#          </td>
#          <td class="available in-range" data-title="r1c1">
#           4
#          </td>
#          <td class="available in-range" data-title="r1c2">
#           5
#          </td>
#          <td class="available in-range" data-title="r1c3">
#           6
#          </td>
#          <td class="available in-range" data-title="r1c4">
#           7
#          </td>
#          <td class="available in-range" data-title="r1c5">
#           8
#          </td>
#          <td class="available in-range" data-title="r1c6">
#           9
#          </td>
#         </tr>
#         <tr>
#          <td class="available in-range" data-title="r2c0">
#           10
#          </td>
#          <td class="available in-range" data-title="r2c1">
#           11
#          </td>
#          <td class="available in-range" data-title="r2c2">
#           12
#          </td>
#          <td class="available in-range" data-title="r2c3">
#           13
#          </td>
#          <td class="available active end-date" data-title="r2c4">
#           14
#          </td>
#          <td class="available" data-title="r2c5">
#           15
#          </td>
#          <td class="available" data-title="r2c6">
#           16
#          </td>
#         </tr>
#         <tr>
#          <td class="available" data-title="r3c0">
#           17
#          </td>
#          <td class="available" data-title="r3c1">
#           18
#          </td>
#          <td class="available" data-title="r3c2">
#           19
#          </td>
#          <td class="available" data-title="r3c3">
#           20
#          </td>
#          <td class="available" data-title="r3c4">
#           21
#          </td>
#          <td class="available" data-title="r3c5">
#           22
#          </td>
#          <td class="available" data-title="r3c6">
#           23
#          </td>
#         </tr>
#         <tr>
#          <td class="available" data-title="r4c0">
#           24
#          </td>
#          <td class="available" data-title="r4c1">
#           25
#          </td>
#          <td class="available" data-title="r4c2">
#           26
#          </td>
#          <td class="available" data-title="r4c3">
#           27
#          </td>
#          <td class="available" data-title="r4c4">
#           28
#          </td>
#          <td class="available" data-title="r4c5">
#           29
#          </td>
#          <td class="available" data-title="r4c6">
#           30
#          </td>
#         </tr>
#         <tr>
#          <td class="available off" data-title="r5c0">
#           1
#          </td>
#          <td class="available off" data-title="r5c1">
#           2
#          </td>
#          <td class="available off" data-title="r5c2">
#           3
#          </td>
#          <td class="available off" data-title="r5c3">
#           4
#          </td>
#          <td class="available off" data-title="r5c4">
#           5
#          </td>
#          <td class="available off" data-title="r5c5">
#           6
#          </td>
#          <td class="available off" data-title="r5c6">
#           7
#          </td>
#         </tr>
#        </tbody>
#       </table>
#      </div>
#     </div>
#    </div>
#    <div class="ranges">
#     <div class="range_inputs">
#      <button class="btn-success applyBtn btn-xs btn btn-small">
#       Confirm
#      </button>
#      <button class="btn-default cancelBtn btn-xs btn btn-small">
#       Cancel
#      </button>
#     </div>
#    </div>
#   </div>
#   <span aria-live="polite" class="select2-hidden-accessible" role="status">
#   </span>
#  </body>
# </html>

# %%
browser.click_link_by_href('/search')
soup = BeautifulSoup(browser.html, 'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1, maximum-scale=1" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    Vipassana Meditation
#   </title>
#   <meta content="Homepage of Vipassana Meditation as taught by S.N. Goenka in the tradition of Sayagyi U Ba Khin" name="Description"/>
#   <meta content="vipassana,meditation,mindfulness,meditate,goenka,buddha,buddhism,dharma,dhamma,silent retreat,silence,tranquility,insight,stress,mind,religion,spirituality,concentration,samadhi,art of living,compassion,peace,harmony,well-being,mental purification,kindness,empathy,sila,panna,metta" name="Keywords"/>
#   <meta content="app-id=1127952631" name="apple-itunes-app"/>
#   <link href="/assets/bodhileaf-4bb63faac0c10feda2a43c1f44d667a8.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://cdnjs.cloudflare.com/ajax/libs/select2/3.5.2/select2.min.css" rel="stylesheet"/>
#   <link href="/assets/application-39020c21d0a2c583d906ea4c88b12dfc.css" media="all" rel="stylesheet"/>
#   <link href="/assets/application.print-f49d1c3fe1d26fc9b38aff3e55a35b85.css" media="print" rel="stylesheet"/>
#   <!--[if IE 7]>
#     <link rel="stylesheet" media="all" href="/assets/application.ie7-08efc4108d9bc12343d7b6d9d2569365.css" />
#     <![endif]-->
#   <!--[if lte IE 8]>
#     <link rel="stylesheet" media="screen" href="/assets/application.ielte8-b1461367d39add6d24b415e56165c203.css" />
#     <![endif]-->
#   <!--[if lt IE 9]>
#     <script src="/assets/html5shiv-6f1980c2b57c886b7b945ba935b65c90.js"></script>
#     <script src="/assets/respond.1.4-ec962dbbf7e6e837bd18f42bddfc8b31.js"></script>
#     <![endif]-->
#   <script async="" src="https://ssl.google-analytics.com/ga.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var _gaq = _gaq || [];
#       _gaq.push(['_setAccount', 'UA-29271111-1']);
#       _gaq.push(['_setDomainName', 'dhamma.org']);
#       _gaq.push(['_trackPageview']);
#
#       (function() {
#         var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#         ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#         var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#       })();
#   </script>
#  </head>
#  <body class=" controller-courses_search action-index" data-locale="en-US" style="">
#   <div id="precontainer">
#    <div class="modal" id="share-modal">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button aria-hidden="true" class="close" data-dismiss="modal" type="button">
#         ×
#        </button>
#        Share Results
#       </div>
#       <div class="modal-body">
#        <p>
#         To share the course search results, copy and share the link below. This link will expire after seven days from today.
#        </p>
#        <textarea class="form-control" data-bind="text: shareUrl()" rows="4">https://www.dhamma.org/en-US/courses/search?share=null</textarea>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="visible-xs" id="mobile-nav-container">
#    <nav class="navbar navbar-default" role="navigation">
#     <div class="container-fluid">
#      <button class="navbar-toggle" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" type="button">
#       <span class="sr-only">
#        Toggle navigation
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#      </button>
#      <div class="navbar-collapse-container">
#       <div class="navbar-collapse">
#        <ul class="nav navbar-nav">
#         <li id="nav-home">
#          <a class="dropdown-toggle" data-original-title="Home" href="/en-US/index" title="">
#           <i class="glyphicon glyphicon-home">
#           </i>
#          </a>
#         </li>
#         <li class="dropdown" id="nav-about">
#          <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#           About
#          </a>
#          <ul class="dropdown-menu" id="about-menu">
#           <li>
#            <a href="/en-US/about/vipassana">
#             What is Vipassana?
#            </a>
#           </li>
#           <li>
#            <a href="/en-US/about/goenka">
#             Mr. S.N. Goenka
#            </a>
#           </li>
#           <li>
#            <a href="/en-US/about/art">
#             The Art of Living: Vipassana Meditation
#            </a>
#           </li>
#           <li>
#            <a href="/en-US/about/code">
#             The Code of Discipline
#            </a>
#           </li>
#           <li>
#            <a href="/en-US/about/qanda">
#             Questions &amp; Answers About the Technique of Vipassana Meditation
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="dropdown" id="nav-courses">
#          <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#           Courses
#          </a>
#          <ul class="dropdown-menu" id="courses-menu">
#           <li>
#            <a href="/en-US/courses/search" rel="nofollow">
#             Search
#            </a>
#           </li>
#           <li class="dropdown">
#            <a href="/en-US/courses/glossary" rel="nofollow">
#             Glossary
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="dropdown" id="nav-locations">
#          <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#           Locations
#          </a>
#          <ul class="dropdown-menu" id="resources-menu">
#           <li>
#            <a href="/en-US/locations/directory" rel="nofollow">
#             Worldwide Directory
#            </a>
#           </li>
#           <li class="dropdown">
#            <a class="dropdown-toggle" href="/en-US/maps#001" rel="nofollow">
#             Maps
#            </a>
#           </li>
#           <li>
#            <a href="/en-US/locations/contacts" rel="nofollow">
#             Contacts
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="dropdown" id="nav-special-sites">
#          <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#           Special Sites
#          </a>
#          <ul class="dropdown-menu" id="special-sites-menu">
#           <li>
#            <a href="/os/" target="_blank">
#             For Old Students
#            </a>
#           </li>
#           <li>
#            <a href="http://www.executive.dhamma.org/" target="_blank">
#             Vipassana for Executives
#            </a>
#           </li>
#           <li>
#            <a href="http://www.prison.dhamma.org/" target="_blank">
#             Vipassana for Prisons
#            </a>
#           </li>
#           <li>
#            <a href="http://www.children.dhamma.org/" target="_blank">
#             Children's Courses
#            </a>
#           </li>
#           <li>
#            <a href="https://www.dhamma.org/en/vri.htm" target="_blank">
#             Vipassana Research Institute
#            </a>
#           </li>
#           <li>
#            <a href="https://www.dhamma.org/en/global.htm" target="_blank">
#             Global Vipassana Pagoda
#            </a>
#           </li>
#           <li>
#            <a href="/en-US/about/mini_anapana">
#             Mini Anapana Meditation
#            </a>
#           </li>
#           <li>
#            <a href="/en-US/about/more_language_sites">
#             More Language Sites
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li id="nav-language">
#          <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#           <i class="glyphicon glyphicon-globe">
#           </i>
#           U.S. English
#          </a>
#          <ul class="dropdown-menu" id="select-language-list">
#           <li>
#            <a href="/bg/courses/search">
#             български
#            </a>
#           </li>
#           <li>
#            <a href="/cs/courses/search">
#             čeština
#            </a>
#           </li>
#           <li>
#            <a href="/de/courses/search">
#             Deutsch
#            </a>
#           </li>
#           <li>
#            <a href="/el/courses/search">
#             Ελληνικά
#            </a>
#           </li>
#           <li>
#            <a href="/en/courses/search">
#             English
#            </a>
#           </li>
#           <li>
#            <a href="/en-US/courses/search">
#             U.S. English
#            </a>
#           </li>
#           <li>
#            <a href="/es/courses/search">
#             Español
#            </a>
#           </li>
#           <li>
#            <a href="/fa/courses/search">
#             فارسی
#            </a>
#           </li>
#           <li>
#            <a href="/fi/courses/search">
#             Suomi
#            </a>
#           </li>
#           <li>
#            <a href="/fr/courses/search">
#             Français
#            </a>
#           </li>
#           <li>
#            <a href="/fr-CA/courses/search">
#             Français canadien
#            </a>
#           </li>
#           <li>
#            <a href="/gu/courses/search">
#             ગુજરાતી
#            </a>
#           </li>
#           <li>
#            <a href="/he/courses/search">
#             עברית
#            </a>
#           </li>
#           <li>
#            <a href="/hi/courses/search">
#             हिन्दी
#            </a>
#           </li>
#           <li>
#            <a href="/hu/courses/search">
#             Magyar
#            </a>
#           </li>
#           <li>
#            <a href="/id/courses/search">
#             Bahasa Indonesia
#            </a>
#           </li>
#           <li>
#            <a href="/it/courses/search">
#             Italiano
#            </a>
#           </li>
#           <li>
#            <a href="/it-CH/courses/search">
#             Svizzero Italiano
#            </a>
#           </li>
#           <li>
#            <a href="/ja/courses/search">
#             日本語
#            </a>
#           </li>
#           <li>
#            <a href="/km/courses/search">
#             ភាសាខ្មែរ
#            </a>
#           </li>
#           <li>
#            <a href="/ko/courses/search">
#             한국어
#            </a>
#           </li>
#           <li>
#            <a href="/lt/courses/search">
#             Lietuvių
#            </a>
#           </li>
#           <li>
#            <a href="/lv/courses/search">
#             Latviešu
#            </a>
#           </li>
#           <li>
#            <a href="/mk/courses/search">
#             македонски
#            </a>
#           </li>
#           <li>
#            <a href="/mr/courses/search">
#             मराठी
#            </a>
#           </li>
#           <li>
#            <a href="/ne/courses/search">
#             नेपाली
#            </a>
#           </li>
#           <li>
#            <a href="/nl/courses/search">
#             Nederlands
#            </a>
#           </li>
#           <li>
#            <a href="/pl/courses/search">
#             Polski
#            </a>
#           </li>
#           <li>
#            <a href="/pt/courses/search">
#             Português
#            </a>
#           </li>
#           <li>
#            <a href="/pt-BR/courses/search">
#             Português do Brasil
#            </a>
#           </li>
#           <li>
#            <a href="/ro/courses/search">
#             Română
#            </a>
#           </li>
#           <li>
#            <a href="/ru/courses/search">
#             русский
#            </a>
#           </li>
#           <li>
#            <a href="/si/courses/search">
#             සිංහල
#            </a>
#           </li>
#           <li>
#            <a href="/sr/courses/search">
#             Српски
#            </a>
#           </li>
#           <li>
#            <a href="/sv/courses/search">
#             Svenska
#            </a>
#           </li>
#           <li>
#            <a href="/ta/courses/search">
#             தமிழ்
#            </a>
#           </li>
#           <li>
#            <a href="/te/courses/search">
#             తెలుగు
#            </a>
#           </li>
#           <li>
#            <a href="/th/courses/search">
#             ไทย
#            </a>
#           </li>
#           <li>
#            <a href="/tr/courses/search">
#             Türkçe
#            </a>
#           </li>
#           <li>
#            <a href="/vi/courses/search">
#             Tiếng Việt
#            </a>
#           </li>
#           <li>
#            <a href="/zh-HANS/courses/search">
#             简体字
#            </a>
#           </li>
#           <li>
#            <a href="/zh-HANT/courses/search">
#             繁體字
#            </a>
#           </li>
#           <li>
#            <p>
#             Translations are in progress. Some pages may have a mix of your selected language and English.
#            </p>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </nav>
#   </div>
#   <div class="container" id="container">
#    <div id="content">
#     <section id="top">
#      <div id="header-container">
#       <header id="page-header">
#        <div class="hidden-xs">
#         <div class="text-right" id="header-left">
#          <h1>
#           Vipassana
#          </h1>
#          <p>
#           As taught by S.N. Goenka
#          </p>
#         </div>
#         <div id="wheel">
#          <img alt="Aniwheel" src="/assets/aniwheel-a87352d07ff79e922e5afbc8775f603b.gif"/>
#         </div>
#         <div class="text-left" id="header-right">
#          <h1>
#           Meditation
#          </h1>
#          <p>
#           in the tradition of Sayagyi U Ba Khin
#          </p>
#         </div>
#         <div class="clearfix">
#         </div>
#        </div>
#        <div class="visible-xs">
#         <div id="wheel">
#          <a href="/en-US/index">
#           <img src="/assets/aniwheel-a87352d07ff79e922e5afbc8775f603b.gif" width="100%"/>
#          </a>
#         </div>
#         <a href="/en-US/index">
#          <h1>
#           Vipassana Meditation
#          </h1>
#         </a>
#         <p class="subhead">
#          As taught by S.N. Goenka
#          <br/>
#          in the tradition of Sayagyi U Ba Khin
#         </p>
#        </div>
#       </header>
#      </div>
#      <div class="hidden-xs">
#       <ul class="nav nav-pills" id="navbar">
#        <li id="nav-home">
#         <a class="dropdown-toggle" data-original-title="Home" href="/en-US/index" title="">
#          <i class="glyphicon glyphicon-home">
#          </i>
#         </a>
#        </li>
#        <li class=" dropdown" id="nav-about">
#         <a class="dropdown-toggle" href="/en-US/about/vipassana">
#          About
#         </a>
#         <ul class="dropdown-menu" id="about-menu" style="left: -38px;">
#          <li>
#           <a href="/en-US/about/vipassana">
#            What is Vipassana?
#           </a>
#          </li>
#          <li>
#           <a href="/en-US/about/goenka">
#            Mr. S.N. Goenka
#           </a>
#          </li>
#          <li>
#           <a href="/en-US/about/art">
#            The Art of Living: Vipassana Meditation
#           </a>
#          </li>
#          <li>
#           <a href="/en-US/about/code">
#            The Code of Discipline
#           </a>
#          </li>
#          <li>
#           <a href="/en-US/about/qanda">
#            Questions &amp; Answers About the Technique of Vipassana Meditation
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="dropdown" id="nav-courses">
#         <a class="dropdown-toggle" href="/en-US/courses/search" rel="nofollow">
#          Courses
#         </a>
#         <ul class="dropdown-menu" id="courses-menu" style="left: -38px;">
#          <li>
#           <a href="/en-US/courses/search" rel="nofollow">
#            Search
#           </a>
#          </li>
#          <li class="dropdown">
#           <a href="/en-US/courses/glossary" rel="nofollow">
#            Glossary
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="dropdown" id="nav-locations">
#         <a href="/en-US/locations/directory" rel="nofollow">
#          Locations
#         </a>
#         <ul class="dropdown-menu" id="resources-menu" style="left: -37.5px;">
#          <li>
#           <a href="/en-US/locations/directory" rel="nofollow">
#            Worldwide Directory
#           </a>
#          </li>
#          <li class="dropdown">
#           <a href="/en-US/maps#001" rel="nofollow">
#            Maps
#           </a>
#          </li>
#          <li>
#           <a href="/en-US/locations/contacts" rel="nofollow">
#            Contacts
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="dropdown" id="nav-special-sites">
#         <a class="dropdown-toggle" href="#">
#          Special Sites
#         </a>
#         <ul class="dropdown-menu" id="special-sites-menu" style="left: -34px;">
#          <li>
#           <a href="/os/" target="_blank">
#            For Old Students
#           </a>
#          </li>
#          <li>
#           <a href="http://www.executive.dhamma.org/" target="_blank">
#            Vipassana for Executives
#           </a>
#          </li>
#          <li>
#           <a href="http://www.prison.dhamma.org/" target="_blank">
#            Vipassana for Prisons
#           </a>
#          </li>
#          <li>
#           <a href="http://www.children.dhamma.org/" target="_blank">
#            Children's Courses
#           </a>
#          </li>
#          <li>
#           <a href="https://www.dhamma.org/en/vri.htm" target="_blank">
#            Vipassana Research Institute
#           </a>
#          </li>
#          <li>
#           <a href="https://www.dhamma.org/en/global.htm" target="_blank">
#            Global Vipassana Pagoda
#           </a>
#          </li>
#          <li>
#           <a href="/en-US/about/mini_anapana">
#            Mini Anapana Meditation
#           </a>
#          </li>
#          <li>
#           <a href="/en-US/about/more_language_sites">
#            More Language Sites
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li id="nav-language">
#         <a href="#set-language">
#          <i class="glyphicon glyphicon-globe">
#          </i>
#          U.S. English
#         </a>
#         <div class="panel panel-default" id="select-language">
#          <div class="panel-body">
#           <h3>
#            Select Language
#           </h3>
#           <ul id="select-language-list">
#            <li>
#             <a href="/bg/courses/search">
#              български
#             </a>
#            </li>
#            <li>
#             <a href="/cs/courses/search">
#              čeština
#             </a>
#            </li>
#            <li>
#             <a href="/de/courses/search">
#              Deutsch
#             </a>
#            </li>
#            <li>
#             <a href="/el/courses/search">
#              Ελληνικά
#             </a>
#            </li>
#            <li>
#             <a href="/en/courses/search">
#              English
#             </a>
#            </li>
#            <li>
#             <a href="/en-US/courses/search">
#              U.S. English
#             </a>
#            </li>
#            <li>
#             <a href="/es/courses/search">
#              Español
#             </a>
#            </li>
#            <li>
#             <a href="/fa/courses/search">
#              فارسی
#             </a>
#            </li>
#            <li>
#             <a href="/fi/courses/search">
#              Suomi
#             </a>
#            </li>
#            <li>
#             <a href="/fr/courses/search">
#              Français
#             </a>
#            </li>
#            <li>
#             <a href="/fr-CA/courses/search">
#              Français canadien
#             </a>
#            </li>
#           </ul>
#           <ul>
#            <li>
#             <a href="/gu/courses/search">
#              ગુજરાતી
#             </a>
#            </li>
#            <li>
#             <a href="/he/courses/search">
#              עברית
#             </a>
#            </li>
#            <li>
#             <a href="/hi/courses/search">
#              हिन्दी
#             </a>
#            </li>
#            <li>
#             <a href="/hu/courses/search">
#              Magyar
#             </a>
#            </li>
#            <li>
#             <a href="/id/courses/search">
#              Bahasa Indonesia
#             </a>
#            </li>
#            <li>
#             <a href="/it/courses/search">
#              Italiano
#             </a>
#            </li>
#            <li>
#             <a href="/it-CH/courses/search">
#              Svizzero Italiano
#             </a>
#            </li>
#            <li>
#             <a href="/ja/courses/search">
#              日本語
#             </a>
#            </li>
#            <li>
#             <a href="/km/courses/search">
#              ភាសាខ្មែរ
#             </a>
#            </li>
#            <li>
#             <a href="/ko/courses/search">
#              한국어
#             </a>
#            </li>
#            <li>
#             <a href="/lt/courses/search">
#              Lietuvių
#             </a>
#            </li>
#           </ul>
#           <ul>
#            <li>
#             <a href="/lv/courses/search">
#              Latviešu
#             </a>
#            </li>
#            <li>
#             <a href="/mk/courses/search">
#              македонски
#             </a>
#            </li>
#            <li>
#             <a href="/mr/courses/search">
#              मराठी
#             </a>
#            </li>
#            <li>
#             <a href="/ne/courses/search">
#              नेपाली
#             </a>
#            </li>
#            <li>
#             <a href="/nl/courses/search">
#              Nederlands
#             </a>
#            </li>
#            <li>
#             <a href="/pl/courses/search">
#              Polski
#             </a>
#            </li>
#            <li>
#             <a href="/pt/courses/search">
#              Português
#             </a>
#            </li>
#            <li>
#             <a href="/pt-BR/courses/search">
#              Português do Brasil
#             </a>
#            </li>
#            <li>
#             <a href="/ro/courses/search">
#              Română
#             </a>
#            </li>
#            <li>
#             <a href="/ru/courses/search">
#              русский
#             </a>
#            </li>
#           </ul>
#           <ul>
#            <li>
#             <a href="/si/courses/search">
#              සිංහල
#             </a>
#            </li>
#            <li>
#             <a href="/sr/courses/search">
#              Српски
#             </a>
#            </li>
#            <li>
#             <a href="/sv/courses/search">
#              Svenska
#             </a>
#            </li>
#            <li>
#             <a href="/ta/courses/search">
#              தமிழ்
#             </a>
#            </li>
#            <li>
#             <a href="/te/courses/search">
#              తెలుగు
#             </a>
#            </li>
#            <li>
#             <a href="/th/courses/search">
#              ไทย
#             </a>
#            </li>
#            <li>
#             <a href="/tr/courses/search">
#              Türkçe
#             </a>
#            </li>
#            <li>
#             <a href="/vi/courses/search">
#              Tiếng Việt
#             </a>
#            </li>
#            <li>
#             <a href="/zh-HANS/courses/search">
#              简体字
#             </a>
#            </li>
#            <li>
#             <a href="/zh-HANT/courses/search">
#              繁體字
#             </a>
#            </li>
#           </ul>
#           <div class="clearfix">
#           </div>
#           <hr/>
#           <p>
#            Translations are in progress. Some pages may have a mix of your selected language and English.
#           </p>
#           <br/>
#          </div>
#         </div>
#        </li>
#       </ul>
#      </div>
#     </section>
#     <section id="main">
#      <br/>
#      <section class="tabbed-header">
#       <h2>
#        Courses
#        <small class="icon hidden-xs">
#         <a data-content='&lt;span class="notes-title"&gt;To find a course:&lt;/span&gt; &amp;nbsp;&amp;nbsp;&amp;nbsp; 1. (Optional) Enter one or more search criteria in the boxes &amp;nbsp;&amp;nbsp;&amp;nbsp; 2. Click the blue search button.&lt;br /&gt;
# &lt;br type="_moz" /&gt;&lt;hr /&gt;&lt;div&gt;
# 	How to locate and apply for courses:  &lt;/div&gt;
# &lt;div&gt;
# 	&lt;ul&gt;
# 		&lt;li&gt;
# 			Select an applicable tab, refine the search options by specifying one or more values per box (re-click the same box to specify additional values) and press the search button&lt;/li&gt;
# 		&lt;li&gt;
# 			Find a suitable course from the list of available courses and click the Apply button to access the online application form in the language of your choice (only the top 100 results are returned; if you do not find a suitable course from the returned result set then refine the search options further and reissue the search)&lt;/li&gt;
# 		&lt;li&gt;
# 			Read carefully the Introduction to the Technique and Code of Discipline which you will be asked to follow during your course.  Fully and completely fill out all the sections of application form and submit it.  An application is required to register for all courses.&lt;/li&gt;
# 		&lt;li&gt;
# 			Await notification.  All correspondence will be through e-mail if you give an e-mail address in your application. Due to the large volume of applications, it may take several weeks before receiving notification.&lt;/li&gt;
# 		&lt;li&gt;
# 			If your application is accepted then we require you to confirm you will be attending in order to secure your place in the course.&lt;/li&gt;
# 	&lt;/ul&gt;
# &lt;/div&gt;' data-html="true" data-original-title="" data-placement="left" data-toggle="popover" href="#" title="">
#          <i class="glyphicon glyphicon-question-sign">
#          </i>
#         </a>
#        </small>
#       </h2>
#       <div id="course-search">
#        <ul class="hidden-xs nav nav-tabs nav-quarters" id="student-type-select">
#         <li class="active" data-bind="css: {active: current_state() == 'NewStudents'}, click: search_new_students">
#          <a class="new-student" href="#">
#           For New Students
#          </a>
#         </li>
#         <li class="" data-bind="css: {active: current_state() == 'OldStudents'}, click: search_old_students">
#          <a class="old-student" href="#">
#           For Old Students
#          </a>
#         </li>
#         <li class="" data-bind="css: {active: current_state() == 'Children'}, click: search_children">
#          <a class="child" href="#">
#           For Children/Teens
#          </a>
#         </li>
#         <li class="" data-bind="css: {active: current_state() == 'Executives'}, click: search_executives">
#          <a class="executive" href="#">
#           For Executives
#          </a>
#         </li>
#        </ul>
#        <div class="search-panel" id="course-search-panel">
#         <div id="search-panel-form">
#          <div class="row">
#           <div class="col-sm-10" id="search-panel-form-inputs">
#            <div class="row">
#             <div class="col-sm-4 visible-xs form-group">
#              <select class="form-control" data-bind="event: { change: change_search_mode }" id="student-type-select-mobile">
#               <option value="NewStudents">
#                For New Students
#               </option>
#               <option value="OldStudents">
#                For Old Students
#               </option>
#               <option value="Children">
#                For Children/Teens
#               </option>
#               <option value="Executives">
#                For Executives
#               </option>
#              </select>
#             </div>
#             <div class="col-sm-4 form-group" data-bind="css: {'has-error': dates_invalid}">
#              <input class="form-control date" data-bind="daterangepicker: {separator: ' \u2014 ', arrows: true, showDropdowns: true,
#           format: date_format(), locale: { applyLabel: 'Confirm',
#           cancelLabel: 'Cancel', fromLabel: 'from',
#           toLabel: 'to' }}, value: search_daterange" id="course-search-date-range" placeholder="Select Date Range"/>
#             </div>
#             <div class="col-sm-4">
#              <div class="form-group">
#               <div class="select2-container select2-container-multi form-control" id="s2id_loc_search">
#                <ul class="select2-choices">
#                 <li class="select2-search-field">
#                  <label class="select2-offscreen" for="s2id_autogen1">
#                  </label>
#                  <input autocapitalize="off" autocomplete="off" autocorrect="off" class="select2-input select2-default" id="s2id_autogen1" placeholder="" spellcheck="false" style="width: 222px;" type="text"/>
#                 </li>
#                </ul>
#                <div class="select2-drop select2-drop-multi select2-display-none">
#                 <ul class="select2-results">
#                  <li class="select2-no-results">
#                   No matches found
#                  </li>
#                  <li class="select2-no-results">
#                   No matches found
#                  </li>
#                  <li class="select2-no-results">
#                   No matches found
#                  </li>
#                 </ul>
#                </div>
#               </div>
#               <input class="form-control" data-bind="select2ValueUpdate: search_region, select2: select2_config_region()" id="loc_search" placeholder="State/Province, Country, Region" style="display: none;" tabindex="-1" type="hidden" value=""/>
#              </div>
#             </div>
#             <div class="col-sm-4">
#              <div class="select2-container select2-container-multi form-control" id="s2id_language-filter">
#               <ul class="select2-choices">
#                <li class="select2-search-field">
#                 <label class="select2-offscreen" for="s2id_autogen2">
#                 </label>
#                 <input autocapitalize="off" autocomplete="off" autocorrect="off" class="select2-input select2-default" id="s2id_autogen2" placeholder="" spellcheck="false" style="width: 222px;" type="text"/>
#                </li>
#               </ul>
#               <div class="select2-drop select2-drop-multi select2-display-none">
#                <ul class="select2-results">
#                 <li class="select2-no-results">
#                  No matches found
#                 </li>
#                 <li class="select2-no-results">
#                  No matches found
#                 </li>
#                </ul>
#               </div>
#              </div>
#              <select class="form-control" data-bind="select2: {placeholder: 'Select Course Language'}, options: instruction_languages, optionsText: 'description', optionsValue: 'iso_code', selectedOptions: search_languages" id="language-filter" multiple="" style="display: none;" tabindex="-1">
#               <option value="af">
#                Afrikaans
#               </option>
#               <option value="am">
#                Amharic
#               </option>
#               <option value="ar">
#                Arabic
#               </option>
#               <option value="bn">
#                Bengali
#               </option>
#               <option value="bg">
#                Bulgarian
#               </option>
#               <option value="my">
#                Burmese
#               </option>
#               <option value="yue">
#                Cantonese
#               </option>
#               <option value="cs">
#                Czech
#               </option>
#               <option value="da">
#                Danish
#               </option>
#               <option value="nl">
#                Dutch
#               </option>
#               <option value="en">
#                English
#               </option>
#               <option value="fi">
#                Finnish
#               </option>
#               <option value="fr">
#                French
#               </option>
#               <option value="de">
#                German
#               </option>
#               <option value="el">
#                Greek
#               </option>
#               <option value="gu">
#                Gujarati
#               </option>
#               <option value="hak">
#                Hakka
#               </option>
#               <option value="he">
#                Hebrew
#               </option>
#               <option value="hi">
#                Hindi
#               </option>
#               <option value="hu">
#                Hungarian
#               </option>
#               <option value="id">
#                Indonesian
#               </option>
#               <option value="it">
#                Italian
#               </option>
#               <option value="ja">
#                Japanese
#               </option>
#               <option value="kn">
#                Kannada
#               </option>
#               <option value="km">
#                Khmer
#               </option>
#               <option value="ko">
#                Korean
#               </option>
#               <option value="lv">
#                Latvian
#               </option>
#               <option value="lt">
#                Lithuanian
#               </option>
#               <option value="ml">
#                Malayalam
#               </option>
#               <option value="cmn">
#                Mandarin
#               </option>
#               <option value="mr">
#                Marathi
#               </option>
#               <option value="mon">
#                Mon
#               </option>
#               <option value="mn">
#                Mongolian
#               </option>
#               <option value="ne">
#                Nepali
#               </option>
#               <option value="new">
#                Newari
#               </option>
#               <option value="no">
#                Norwegian
#               </option>
#               <option value="fa">
#                Persian (Farsi)
#               </option>
#               <option value="pl">
#                Polish
#               </option>
#               <option value="pt">
#                Portuguese
#               </option>
#               <option value="pa">
#                Punjabi
#               </option>
#               <option value="ro">
#                Romanian
#               </option>
#               <option value="ru">
#                Russian
#               </option>
#               <option value="sr">
#                Serbian
#               </option>
#               <option value="hbs">
#                Serbo-Croatian
#               </option>
#               <option value="shn">
#                Shan
#               </option>
#               <option value="si">
#                Sinhala
#               </option>
#               <option value="sl">
#                Slovenian
#               </option>
#               <option value="es">
#                Spanish
#               </option>
#               <option value="sw">
#                Swahili
#               </option>
#               <option value="sv">
#                Swedish
#               </option>
#               <option value="tl">
#                Tagalog
#               </option>
#               <option value="ta">
#                Tamil
#               </option>
#               <option value="te">
#                Telugu
#               </option>
#               <option value="th">
#                Thai
#               </option>
#               <option value="tr">
#                Turkish
#               </option>
#               <option value="vi">
#                Vietnamese
#               </option>
#              </select>
#             </div>
#            </div>
#            <div class="row">
#             <!-- ko if: showAdvancedOptions -->
#             <!-- /ko -->
#             <!-- ko if: current_state() == 'OldStudents' -->
#             <!-- /ko -->
#             <div class="col-sm-4">
#             </div>
#            </div>
#           </div>
#           <div class="col-sm-2">
#            <a class="btn btn-apply center" data-bind="click: performSearch" href="/search" style="width:100%;">
#             <i class="glyphicon glyphicon-search">
#             </i>
#            </a>
#            <!-- ko if: share() -->
#            <!-- /ko -->
#           </div>
#          </div>
#         </div>
#         <div class="search-toolbar btn-toolbar" id="course-list-setting">
#          <!-- ko if: results_on_search -->
#          <!-- /ko -->
#         </div>
#        </div>
#       </div>
#      </section>
#      <section data-bind="template: current_view" id="course-search-results">
#       <!-- Template for rendering list of results -->
#       <!-- ko foreach: {data: courses, afterRender: postprocess_course} -->
#       <!-- /ko -->
#      </section>
#      <!-- ko if: results_on_search -->
#      <!-- /ko -->
#      <!-- ko if: searched -->
#      <!-- /ko -->
#      <div id="course-search-instructions">
#       <!-- ko if: current_state() == 'NewStudents' -->
#       <p>
#        <a name="10-Day">
#        </a>
#        <span class="notes-title">
#         10-day Courses
#        </span>
#        are an introductory course to Vipassana Meditation where the technique is taught step-by-step each day. The courses begin after a 2 - 4 pm registration period and orientation, followed by 10 full days of meditation, and end the morning of the 11th day by 7:30 am.
#       </p>
#       <!-- /ko -->
#       <!-- ko if: current_state() == 'OldStudents' -->
#       <!-- /ko -->
#       <!-- ko if: current_state() == 'Children' -->
#       <!-- /ko -->
#       <!-- ko if: current_state() == 'Executives' -->
#       <!-- /ko -->
#      </div>
#      <script id="course_status" type="text/html">
#       &lt;div data-bind="foreach: status"&gt;
# &lt;span data-bind="html: status_text, classes: status_classes"&gt;&lt;/span&gt;
# &lt;/div&gt;
#      </script>
#      <div id="location-modal-container">
#      </div>
#     </section>
#    </div>
#    <div id="footer">
#     <hr/>
#     <p>
#      Dhamma.org
#     </p>
#     <p>
#      <a href="/en-US/about/privacy">
#       Privacy Policy
#      </a>
#      |
#      <a href="mailto:webmaster@dhamma.org">
#       Email Webmaster
#      </a>
#     </p>
#     <p>
#      <a href="https://itunes.apple.com/us/app/dhamma-org/id1127952631?mt=8">
#       <img alt="App store us uk" src="/assets/app-store-us-uk-475b9d8be87e34a116c3763a3640c26f.svg" width="135"/>
#      </a>
#      <a href="https://play.google.com/store/apps/details?id=org.dhamma">
#       <img alt="Play store badge" src="/assets/play-store-badge-fd9ac7cfac52af3d94574d52ae0f29d9.png" width="155"/>
#      </a>
#     </p>
#     <p>
#      <a href="/en-US/about/mobile-app">
#       Dhamma.org Mobile App
#      </a>
#     </p>
#    </div>
#   </div>
#   <script src="/assets/application-bd78d5e3413c14cb87460a1c58872ab0.js" type="text/javascript">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/select2/3.5.2/select2.min.js" type="text/javascript">
#   </script>
#   <img alt="Spinner" class="hidden" src="/assets/spinner-88b380ce4d66f6d126304c5acda1da57.gif"/>
#   <script type="text/javascript">
#    $(document).ajaxStart(function() {
#         $.blockUI({
# message: '&lt;div id="block-spinner"&gt;&lt;/div&gt;',
#           css: {
#             color: '#029',
#             left: 0,
#             border: 0,
#             backgroundColor: 'transparent',
#             width: '100%',
#             height: '100px',
#           },
#           baseZ: 10000
#           });
#       }).ajaxStop($.unblockUI);
#   </script>
#   <script type="text/javascript">
#    $(function() {
#
#       });
#   </script>
#   <script type="text/javascript">
#    $(".listOfCountriesNotYet").popover({
#       content: ""
#     });
#   </script>
#   <script id="list" type="text/html">
#    &lt;!-- Template for rendering list of results --&gt;
# &lt;!-- ko foreach: {data: courses, afterRender: postprocess_course} --&gt;
# &lt;div class="visible-xs course"&gt;
#   &lt;div class="row"&gt;
#     &lt;div class="col-xs-2"&gt;
#       &lt;div data-bind="with: location"&gt;
#         &lt;div class="flag" data-bind="css: flag_icon_class" width=35 height=35&gt;&lt;/div&gt;
#       &lt;/div&gt;
#     &lt;/div&gt;
#     &lt;div class="col-xs-10"&gt;
#       &lt;h3&gt;
#         &lt;span class="date" data-bind="html: localizedStartDate"&gt;&lt;/span&gt;
#         &lt;!-- ko if: course_end_date != null --&gt;
#         -
#         &lt;span class="date" data-bind="html: localizedEndDate"&gt;&lt;/span&gt;
#         &lt;!-- /ko --&gt;
#       &lt;/h3&gt;
#       &lt;div class="course-location" data-bind="with: location"&gt;
#         &lt;h4 class="course-location-title"&gt;
#           &lt;!-- ko if: dhamma_name() --&gt;
#             &lt;!-- ko if: $root.show_center_links() --&gt;
#             &lt;a href="##" data-toggle="dropdown" data-bind="text: dhamma_name"&gt;&lt;/a&gt;,
#             &lt;!-- /ko --&gt;
#             &lt;!-- ko if: !$root.show_center_links() --&gt;
#             &lt;span data-bind="text: dhamma_name"&gt;&lt;/span&gt;,
#             &lt;!-- /ko --&gt;
#           &lt;!-- /ko --&gt;
#           &lt;!-- ko if: $root.show_center_links() --&gt;
#           &lt;ul class="dropdown-menu"&gt;
#             &lt;!-- ko if: location_languages().length &gt; 1 --&gt;
#             &lt;!-- ko foreach: location_languages() --&gt;
#             &lt;li&gt;
#               &lt;a target="_blank" href="#" data-bind="attr:{href:schedule_url}"&gt;&lt;i class="glyphicon glyphicon-calendar" /&gt; Courses (&lt;span data-bind="text: description"&gt;&lt;/span&gt;)&lt;/a&gt;
#             &lt;/li&gt;
#             &lt;!-- /ko --&gt;
#             &lt;!-- /ko --&gt;
#             &lt;!-- ko if: location_languages().length == 1 --&gt;
#               &lt;!-- ko with: location_languages()[0] --&gt;
#               &lt;li&gt;&lt;a href="#" data-bind="attr:{href:schedule_url}" target="_blank"&gt;&lt;i class="glyphicon glyphicon-calendar" /&gt; Courses&lt;/a&gt;&lt;/li&gt;
#               &lt;!-- /ko --&gt;
#             &lt;!-- /ko --&gt;
#             &lt;li&gt;&lt;a target="_blank" data-bind="attr: {href: website_url}"&gt;&lt;i class="glyphicon glyphicon-home" /&gt; Website&lt;/a&gt;&lt;/li&gt;
#             &lt;!-- ko if: $root.show_map_link() --&gt;
#             &lt;li&gt;&lt;a target="_blank" data-bind="css:{disabled: !(map_url() != null &amp;&amp; map_url().length &gt; 0)}, attr: {href: map_url}"&gt;&lt;i class="glyphicon glyphicon-map-marker" /&gt; Map&lt;/a&gt;&lt;/li&gt;
#             &lt;!-- /ko --&gt;
#           &lt;/ul&gt;
#           &lt;!-- /ko --&gt;
#           &lt;!-- ko if: sub_location() != null &amp;&amp; sub_location_url() != null --&gt;
#             &lt;a target="_blank" data-bind="attr: {href: sub_location_url}, text: sub_location"&gt;&lt;/a&gt;
#           &lt;!-- /ko --&gt;
#           &lt;!-- ko if: sub_location() != null &amp;&amp; sub_location_url() == null --&gt;
#             &lt;span data-bind="text: sub_location"&gt;&lt;/span&gt;
#           &lt;!-- /ko --&gt;
#           &lt;!-- ko if: sub_location() == null --&gt;
#             &lt;span data-bind="text: city_province_country"&gt;&lt;/span&gt;
#           &lt;!-- /ko --&gt;
#           &lt;span data-bind="css: pin_class"&gt;&lt;/span&gt;
#         &lt;/h4&gt;
#         &lt;!-- /ko --&gt;
#       &lt;/div&gt;
#       &lt;h4&gt;
#         &lt;span class="info"&gt;&lt;span data-bind="html: course_type"&gt;&lt;/span&gt;&lt;/span&gt;
#         &lt;!-- ko if: haveCourseInstructionLanguages --&gt;
#           &amp;nbsp;&amp;nbsp;
#           &lt;!-- ko if: course_instruction_languages().length &gt; 1 --&gt;
#           &lt;span class="info course-languages" href="##" data-bind="foreach: course_instruction_languages"&gt;
#             &lt;span data-bind="text: $data"&gt;&lt;/span&gt;
#           &lt;/span&gt;
#           &lt;!-- /ko --&gt;
#           &lt;!-- ko if: course_instruction_languages().length == 1 --&gt;
#           &lt;span class="info course-languages" data-html="true" data-bind="foreach: course_instruction_languages"&gt;
#             &lt;span data-bind="text: $data"&gt;&lt;/span&gt;
#           &lt;/span&gt;
#           &lt;!-- /ko --&gt;
#         &lt;!-- /ko --&gt;
#       &lt;/h4&gt;
#       &lt;h4 class="info" data-bind="template: 'course_status'"&gt;&lt;/h4&gt;
#     &lt;/div&gt;
#   &lt;/div&gt;
#   &lt;div data-bind="if: canApply"&gt;
#   &lt;!-- ko if: hasManyApplyLanguages --&gt;
#   &lt;div class="btn-group btn-group-apply"&gt;
#     &lt;button type="button" class="btn btn-apply dropdown-toggle" data-toggle="dropdown"&gt;
#       Apply &lt;span class="caret caret-white"&gt;&lt;/span&gt;
#     &lt;/button&gt;
#     &lt;ul class="dropdown-menu" role="menu" data-bind="foreach: apply_languages"&gt;
#       &lt;li&gt;
#         &lt;a href="#" target="_blank" data-bind="text: description_with_indicator, attr:{href:apply_link_url}, click: handle_apply_click"&gt;&lt;/a&gt;
#       &lt;/li&gt;
#     &lt;/ul&gt;
#   &lt;/div&gt;
#   &lt;!-- /ko --&gt;
#   &lt;!-- ko ifnot: hasManyApplyLanguages --&gt;
#     &lt;!-- ko foreach: apply_languages  --&gt;
#     &lt;a class="btn btn-apply" target="_blank" data-bind="attr: {href:apply_link_url}, click: handle_apply_click"&gt;
#       Apply&lt;span data-bind="visible: apply_override"&gt;*&lt;/span&gt;
#     &lt;/a&gt;
#     &lt;!-- /ko --&gt;
#   &lt;!-- /ko --&gt;
# &lt;/div&gt;
#
# &lt;/div&gt;
# &lt;div class="hidden-xs list-item course row"&gt;
#   &lt;div class="col-sm-2 col-apply"&gt;
#     &lt;h3&gt;&lt;/h3&gt;
#     &lt;div data-bind="if: canApply"&gt;
#   &lt;!-- ko if: hasManyApplyLanguages --&gt;
#   &lt;div class="btn-group btn-group-apply"&gt;
#     &lt;button type="button" class="btn btn-apply dropdown-toggle" data-toggle="dropdown"&gt;
#       Apply &lt;span class="caret caret-white"&gt;&lt;/span&gt;
#     &lt;/button&gt;
#     &lt;ul class="dropdown-menu" role="menu" data-bind="foreach: apply_languages"&gt;
#       &lt;li&gt;
#         &lt;a href="#" target="_blank" data-bind="text: description_with_indicator, attr:{href:apply_link_url}, click: handle_apply_click"&gt;&lt;/a&gt;
#       &lt;/li&gt;
#     &lt;/ul&gt;
#   &lt;/div&gt;
#   &lt;!-- /ko --&gt;
#   &lt;!-- ko ifnot: hasManyApplyLanguages --&gt;
#     &lt;!-- ko foreach: apply_languages  --&gt;
#     &lt;a class="btn btn-apply" target="_blank" data-bind="attr: {href:apply_link_url}, click: handle_apply_click"&gt;
#       Apply&lt;span data-bind="visible: apply_override"&gt;*&lt;/span&gt;
#     &lt;/a&gt;
#     &lt;!-- /ko --&gt;
#   &lt;!-- /ko --&gt;
# &lt;/div&gt;
#
#   &lt;/div&gt;
#   &lt;div class="col-sm-3"&gt;
#     &lt;div class="course-info"&gt;
#       &lt;h3&gt;
#         &lt;span class="date" data-bind="html: localizedStartDate"&gt;&lt;/span&gt;
#         &lt;!-- ko if: course_end_date != null --&gt;
#         -
#         &lt;span class="date" data-bind="html: localizedEndDate"&gt;&lt;/span&gt;
#         &lt;!-- /ko --&gt;
#       &lt;/h3&gt;
#       &lt;h4&gt;
#         &lt;a class="info" data-placement="bottom" data-toggle="tooltip" href="##" data-html="true" data-bind="attr: {title: course_type_hint}"&gt;&lt;span data-bind="html: course_type"&gt;&lt;/span&gt;&lt;/a&gt;
#         &lt;!-- ko if: haveCourseInstructionLanguages --&gt;
#           &lt;br /&gt;
#           &lt;!-- ko if: course_instruction_languages().length &gt; 1 --&gt;
#           &lt;a class="info course-languages" href="##" data-html="true" data-toggle="tooltip" data-placement="bottom" data-bind="attr: {title: instruction_languages_tooltip}, foreach: course_instruction_languages"&gt;
#             &lt;span data-bind="text: $data"&gt;&lt;/span&gt;
#           &lt;/a&gt;
#           &lt;!-- /ko --&gt;
#           &lt;!-- ko if: course_instruction_languages().length == 1 --&gt;
#           &lt;span class="info course-languages" data-html="true" data-toggle="tooltip" data-placement="bottom" data-bind="attr: {title: instruction_languages_tooltip}, foreach: course_instruction_languages"&gt;
#             &lt;span data-bind="text: $data"&gt;&lt;/span&gt;
#           &lt;/span&gt;
#           &lt;!-- /ko --&gt;
#         &lt;!-- /ko --&gt;
#       &lt;/h4&gt;
#       &lt;h4 class="info" data-bind="template: 'course_status'"&gt;&lt;/h4&gt;
#     &lt;/div&gt;
#   &lt;/div&gt;
#   &lt;div class="col-sm-4"&gt;
#     &lt;div class="course-location" data-bind="with: location"&gt;
#       &lt;div class="flag pull-left" data-bind="css: flag_icon_class" width=35 height=35&gt;&lt;/div&gt;
#       &lt;div class="course-location-meta"&gt;
#         &lt;div class="course-location-title"&gt;
#           &lt;!-- ko if: sub_location() != null &amp;&amp; sub_location_url() != null --&gt;
#             &lt;a target="_blank" data-bind="attr: {href: sub_location_url}, text: sub_location"&gt;&lt;/a&gt;
#           &lt;!-- /ko --&gt;
#           &lt;!-- ko if: sub_location() != null &amp;&amp; sub_location_url() == null --&gt;
#             &lt;span data-bind="text: sub_location"&gt;&lt;/span&gt;
#           &lt;!-- /ko --&gt;
#           &lt;!-- ko if: sub_location() == null --&gt;
#             &lt;span data-bind="text: city_province_country"&gt;&lt;/span&gt;
#           &lt;!-- /ko --&gt;
#           &lt;span data-bind="css: pin_class"&gt;&lt;/span&gt;
#         &lt;/div&gt;
#         &lt;!-- ko if: dhamma_name() --&gt;
#           &lt;!-- ko if: $root.show_center_links() --&gt;
#           &lt;a class="underline location-link" target="_blank" href="##"
#             data-toggle="modal" data-bind="text: dhamma_name, attr: { 'data-id':
# ...
#             Aug
#            </option>
#            <option value="8">
#             Sep
#            </option>
#            <option value="9">
#             Oct
#            </option>
#            <option selected="selected" value="10">
#             Nov
#            </option>
#            <option value="11">
#             Dec
#            </option>
#           </select>
#           <select class="yearselect">
#            <option value="1968">
#             1968
#            </option>
#            <option value="1969">
#             1969
#            </option>
#            <option value="1970">
#             1970
#            </option>
#            <option value="1971">
#             1971
#            </option>
#            <option value="1972">
#             1972
#            </option>
#            <option value="1973">
#             1973
#            </option>
#            <option value="1974">
#             1974
#            </option>
#            <option value="1975">
#             1975
#            </option>
#            <option value="1976">
#             1976
#            </option>
#            <option value="1977">
#             1977
#            </option>
#            <option value="1978">
#             1978
#            </option>
#            <option value="1979">
#             1979
#            </option>
#            <option value="1980">
#             1980
#            </option>
#            <option value="1981">
#             1981
#            </option>
#            <option value="1982">
#             1982
#            </option>
#            <option value="1983">
#             1983
#            </option>
#            <option value="1984">
#             1984
#            </option>
#            <option value="1985">
#             1985
#            </option>
#            <option value="1986">
#             1986
#            </option>
#            <option value="1987">
#             1987
#            </option>
#            <option value="1988">
#             1988
#            </option>
#            <option value="1989">
#             1989
#            </option>
#            <option value="1990">
#             1990
#            </option>
#            <option value="1991">
#             1991
#            </option>
#            <option value="1992">
#             1992
#            </option>
#            <option value="1993">
#             1993
#            </option>
#            <option value="1994">
#             1994
#            </option>
#            <option value="1995">
#             1995
#            </option>
#            <option value="1996">
#             1996
#            </option>
#            <option value="1997">
#             1997
#            </option>
#            <option value="1998">
#             1998
#            </option>
#            <option value="1999">
#             1999
#            </option>
#            <option value="2000">
#             2000
#            </option>
#            <option value="2001">
#             2001
#            </option>
#            <option value="2002">
#             2002
#            </option>
#            <option value="2003">
#             2003
#            </option>
#            <option value="2004">
#             2004
#            </option>
#            <option value="2005">
#             2005
#            </option>
#            <option value="2006">
#             2006
#            </option>
#            <option value="2007">
#             2007
#            </option>
#            <option value="2008">
#             2008
#            </option>
#            <option value="2009">
#             2009
#            </option>
#            <option value="2010">
#             2010
#            </option>
#            <option value="2011">
#             2011
#            </option>
#            <option value="2012">
#             2012
#            </option>
#            <option value="2013">
#             2013
#            </option>
#            <option value="2014">
#             2014
#            </option>
#            <option value="2015">
#             2015
#            </option>
#            <option value="2016">
#             2016
#            </option>
#            <option value="2017">
#             2017
#            </option>
#            <option selected="selected" value="2018">
#             2018
#            </option>
#            <option value="2019">
#             2019
#            </option>
#            <option value="2020">
#             2020
#            </option>
#            <option value="2021">
#             2021
#            </option>
#            <option value="2022">
#             2022
#            </option>
#            <option value="2023">
#             2023
#            </option>
#           </select>
#          </th>
#          <th class="next available">
#           <i class="icon-arrow-right glyphicon glyphicon-arrow-right">
#           </i>
#          </th>
#         </tr>
#         <tr>
#          <th>
#           Su
#          </th>
#          <th>
#           Mo
#          </th>
#          <th>
#           Tu
#          </th>
#          <th>
#           We
#          </th>
#          <th>
#           Th
#          </th>
#          <th>
#           Fr
#          </th>
#          <th>
#           Sa
#          </th>
#         </tr>
#        </thead>
#        <tbody>
#         <tr>
#          <td class="available off" data-title="r0c0">
#           28
#          </td>
#          <td class="available off" data-title="r0c1">
#           29
#          </td>
#          <td class="available off" data-title="r0c2">
#           30
#          </td>
#          <td class="available off" data-title="r0c3">
#           31
#          </td>
#          <td class="available" data-title="r0c4">
#           1
#          </td>
#          <td class="available" data-title="r0c5">
#           2
#          </td>
#          <td class="available" data-title="r0c6">
#           3
#          </td>
#         </tr>
#         <tr>
#          <td class="available" data-title="r1c0">
#           4
#          </td>
#          <td class="available" data-title="r1c1">
#           5
#          </td>
#          <td class="available" data-title="r1c2">
#           6
#          </td>
#          <td class="available" data-title="r1c3">
#           7
#          </td>
#          <td class="available" data-title="r1c4">
#           8
#          </td>
#          <td class="available" data-title="r1c5">
#           9
#          </td>
#          <td class="available" data-title="r1c6">
#           10
#          </td>
#         </tr>
#         <tr>
#          <td class="available" data-title="r2c0">
#           11
#          </td>
#          <td class="available" data-title="r2c1">
#           12
#          </td>
#          <td class="available" data-title="r2c2">
#           13
#          </td>
#          <td class="available active start-date" data-title="r2c3">
#           14
#          </td>
#          <td class="available in-range" data-title="r2c4">
#           15
#          </td>
#          <td class="available in-range" data-title="r2c5">
#           16
#          </td>
#          <td class="available in-range" data-title="r2c6">
#           17
#          </td>
#         </tr>
#         <tr>
#          <td class="available in-range" data-title="r3c0">
#           18
#          </td>
#          <td class="available in-range" data-title="r3c1">
#           19
#          </td>
#          <td class="available in-range" data-title="r3c2">
#           20
#          </td>
#          <td class="available in-range" data-title="r3c3">
#           21
#          </td>
#          <td class="available in-range" data-title="r3c4">
#           22
#          </td>
#          <td class="available in-range" data-title="r3c5">
#           23
#          </td>
#          <td class="available in-range" data-title="r3c6">
#           24
#          </td>
#         </tr>
#         <tr>
#          <td class="available in-range" data-title="r4c0">
#           25
#          </td>
#          <td class="available in-range" data-title="r4c1">
#           26
#          </td>
#          <td class="available in-range" data-title="r4c2">
#           27
#          </td>
#          <td class="available in-range" data-title="r4c3">
#           28
#          </td>
#          <td class="available in-range" data-title="r4c4">
#           29
#          </td>
#          <td class="available in-range" data-title="r4c5">
#           30
#          </td>
#          <td class="available off in-range" data-title="r4c6">
#           1
#          </td>
#         </tr>
#         <tr>
#          <td class="available off in-range" data-title="r5c0">
#           2
#          </td>
#          <td class="available off in-range" data-title="r5c1">
#           3
#          </td>
#          <td class="available off in-range" data-title="r5c2">
#           4
#          </td>
#          <td class="available off in-range" data-title="r5c3">
#           5
#          </td>
#          <td class="available off in-range" data-title="r5c4">
#           6
#          </td>
#          <td class="available off in-range" data-title="r5c5">
#           7
#          </td>
#          <td class="available off in-range" data-title="r5c6">
#           8
#          </td>
#         </tr>
#        </tbody>
#       </table>
#      </div>
#     </div>
#    </div>
#    <div class="calendar-container right">
#     <div class="daterangepicker_end_input">
#      <label for="daterangepicker_end">
#       to
#      </label>
#      <input class="form-control input-mini" disabled="" name="daterangepicker_end" style="text-align:center;" type="text" value=""/>
#     </div>
#     <div class="calendar right" style="display: block;">
#      <div class="calendar-date">
#       <table class="table-condensed">
#        <thead>
#         <tr>
#          <th class="prev available">
#           <i class="icon-arrow-left glyphicon glyphicon-arrow-left">
#           </i>
#          </th>
#          <th colspan="5" style="width: auto">
#           <select class="monthselect">
#            <option value="0">
#             Jan
#            </option>
#            <option value="1">
#             Feb
#            </option>
#            <option value="2">
#             Mar
#            </option>
#            <option value="3">
#             Apr
#            </option>
#            <option value="4">
#             May
#            </option>
#            <option value="5">
#             Jun
#            </option>
#            <option value="6">
#             Jul
#            </option>
#            <option value="7">
#             Aug
#            </option>
#            <option value="8">
#             Sep
#            </option>
#            <option value="9">
#             Oct
#            </option>
#            <option selected="selected" value="10">
#             Nov
#            </option>
#            <option value="11">
#             Dec
#            </option>
#           </select>
#           <select class="yearselect">
#            <option value="2018">
#             2018
#            </option>
#            <option selected="selected" value="2019">
#             2019
#            </option>
#            <option value="2020">
#             2020
#            </option>
#            <option value="2021">
#             2021
#            </option>
#            <option value="2022">
#             2022
#            </option>
#            <option value="2023">
#             2023
#            </option>
#            <option value="2024">
#             2024
#            </option>
#           </select>
#          </th>
#          <th class="next available">
#           <i class="icon-arrow-right glyphicon glyphicon-arrow-right">
#           </i>
#          </th>
#         </tr>
#         <tr>
#          <th>
#           Su
#          </th>
#          <th>
#           Mo
#          </th>
#          <th>
#           Tu
#          </th>
#          <th>
#           We
#          </th>
#          <th>
#           Th
#          </th>
#          <th>
#           Fr
#          </th>
#          <th>
#           Sa
#          </th>
#         </tr>
#        </thead>
#        <tbody>
#         <tr>
#          <td class="available off in-range" data-title="r0c0">
#           27
#          </td>
#          <td class="available off in-range" data-title="r0c1">
#           28
#          </td>
#          <td class="available off in-range" data-title="r0c2">
#           29
#          </td>
#          <td class="available off in-range" data-title="r0c3">
#           30
#          </td>
#          <td class="available off in-range" data-title="r0c4">
#           31
#          </td>
#          <td class="available in-range" data-title="r0c5">
#           1
#          </td>
#          <td class="available in-range" data-title="r0c6">
#           2
#          </td>
#         </tr>
#         <tr>
#          <td class="available in-range" data-title="r1c0">
#           3
#          </td>
#          <td class="available in-range" data-title="r1c1">
#           4
#          </td>
#          <td class="available in-range" data-title="r1c2">
#           5
#          </td>
#          <td class="available in-range" data-title="r1c3">
#           6
#          </td>
#          <td class="available in-range" data-title="r1c4">
#           7
#          </td>
#          <td class="available in-range" data-title="r1c5">
#           8
#          </td>
#          <td class="available in-range" data-title="r1c6">
#           9
#          </td>
#         </tr>
#         <tr>
#          <td class="available in-range" data-title="r2c0">
#           10
#          </td>
#          <td class="available in-range" data-title="r2c1">
#           11
#          </td>
#          <td class="available in-range" data-title="r2c2">
#           12
#          </td>
#          <td class="available in-range" data-title="r2c3">
#           13
#          </td>
#          <td class="available active end-date" data-title="r2c4">
#           14
#          </td>
#          <td class="available" data-title="r2c5">
#           15
#          </td>
#          <td class="available" data-title="r2c6">
#           16
#          </td>
#         </tr>
#         <tr>
#          <td class="available" data-title="r3c0">
#           17
#          </td>
#          <td class="available" data-title="r3c1">
#           18
#          </td>
#          <td class="available" data-title="r3c2">
#           19
#          </td>
#          <td class="available" data-title="r3c3">
#           20
#          </td>
#          <td class="available" data-title="r3c4">
#           21
#          </td>
#          <td class="available" data-title="r3c5">
#           22
#          </td>
#          <td class="available" data-title="r3c6">
#           23
#          </td>
#         </tr>
#         <tr>
#          <td class="available" data-title="r4c0">
#           24
#          </td>
#          <td class="available" data-title="r4c1">
#           25
#          </td>
#          <td class="available" data-title="r4c2">
#           26
#          </td>
#          <td class="available" data-title="r4c3">
#           27
#          </td>
#          <td class="available" data-title="r4c4">
#           28
#          </td>
#          <td class="available" data-title="r4c5">
#           29
#          </td>
#          <td class="available" data-title="r4c6">
#           30
#          </td>
#         </tr>
#         <tr>
#          <td class="available off" data-title="r5c0">
#           1
#          </td>
#          <td class="available off" data-title="r5c1">
#           2
#          </td>
#          <td class="available off" data-title="r5c2">
#           3
#          </td>
#          <td class="available off" data-title="r5c3">
#           4
#          </td>
#          <td class="available off" data-title="r5c4">
#           5
#          </td>
#          <td class="available off" data-title="r5c5">
#           6
#          </td>
#          <td class="available off" data-title="r5c6">
#           7
#          </td>
#         </tr>
#        </tbody>
#       </table>
#      </div>
#     </div>
#    </div>
#    <div class="ranges">
#     <div class="range_inputs">
#      <button class="btn-success applyBtn btn-xs btn btn-small">
#       Confirm
#      </button>
#      <button class="btn-default cancelBtn btn-xs btn btn-small">
#       Cancel
#      </button>
#     </div>
#    </div>
#   </div>
#   <span aria-live="polite" class="select2-hidden-accessible" role="status">
#   </span>
#   <div class="blockUI" style="display:none">
#   </div>
#   <div class="blockUI blockOverlay" style="z-index: 10000; border: none; margin: 0px; padding: 0px; width: 100%; height: 100%; top: 0px; left: 0px; background-color: rgb(0, 0, 0); opacity: 0; cursor: wait; position: fixed;">
#   </div>
#   <div class="blockUI blockMsg blockPage" style="z-index: 10011; position: fixed; padding: 0px; margin: 0px; width: 100%; top: 40%; left: 0px; text-align: center; color: rgb(0, 34, 153); border: 0px; background-color: transparent; cursor: wait; height: 100px; opacity: 0;">
#    <div id="block-spinner">
#    </div>
#   </div>
#  </body>
# </html>

# %%
print(soup.find_all('div'))
# Out:
# [<div id="precontainer">
# <div class="modal" id="share-modal">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button">×</button>
# Share Results
# </div>
# <div class="modal-body">
# <p>To share the course search results, copy and share the link below. This link will expire after seven days from today.</p>
# <textarea class="form-control" data-bind="text: shareUrl()" rows="4">https://www.dhamma.org/en-US/courses/search?share=null</textarea>
# </div>
# </div>
# </div>
# </div>
# </div>, <div class="modal" id="share-modal">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button">×</button>
# Share Results
# </div>
# <div class="modal-body">
# <p>To share the course search results, copy and share the link below. This link will expire after seven days from today.</p>
# <textarea class="form-control" data-bind="text: shareUrl()" rows="4">https://www.dhamma.org/en-US/courses/search?share=null</textarea>
# </div>
# </div>
# </div>
# </div>, <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button">×</button>
# Share Results
# </div>
# <div class="modal-body">
# <p>To share the course search results, copy and share the link below. This link will expire after seven days from today.</p>
# <textarea class="form-control" data-bind="text: shareUrl()" rows="4">https://www.dhamma.org/en-US/courses/search?share=null</textarea>
# </div>
# </div>
# </div>, <div class="modal-content">
# <div class="modal-header">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button">×</button>
# Share Results
# </div>
# <div class="modal-body">
# <p>To share the course search results, copy and share the link below. This link will expire after seven days from today.</p>
# <textarea class="form-control" data-bind="text: shareUrl()" rows="4">https://www.dhamma.org/en-US/courses/search?share=null</textarea>
# </div>
# </div>, <div class="modal-header">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button">×</button>
# Share Results
# </div>, <div class="modal-body">
# <p>To share the course search results, copy and share the link below. This link will expire after seven days from today.</p>
# <textarea class="form-control" data-bind="text: shareUrl()" rows="4">https://www.dhamma.org/en-US/courses/search?share=null</textarea>
# </div>, <div class="visible-xs" id="mobile-nav-container">
# <nav class="navbar navbar-default" role="navigation">
# <div class="container-fluid">
# <button class="navbar-toggle" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <div class="navbar-collapse-container">
# <div class="navbar-collapse">
# <ul class="nav navbar-nav">
# <li id="nav-home">
# <a class="dropdown-toggle" data-original-title="Home" href="/en-US/index" title="">
# <i class="glyphicon glyphicon-home"></i>
# </a> </li>
# <li class="dropdown" id="nav-about">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">About</a>
# <ul class="dropdown-menu" id="about-menu">
# <li><a href="/en-US/about/vipassana">What is Vipassana?</a></li>
# <li><a href="/en-US/about/goenka">Mr. S.N. Goenka</a></li>
# <li><a href="/en-US/about/art">The Art of Living: Vipassana Meditation</a></li>
# <li><a href="/en-US/about/code">The Code of Discipline</a></li>
# <li><a href="/en-US/about/qanda">Questions &amp; Answers About the Technique of Vipassana Meditation</a></li>
# </ul>
# </li>
# <li class="dropdown" id="nav-courses">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Courses</a>
# <ul class="dropdown-menu" id="courses-menu">
# <li>
# <a href="/en-US/courses/search" rel="nofollow">Search</a>
# </li>
# <li class="dropdown">
# <a href="/en-US/courses/glossary" rel="nofollow">Glossary</a>
# </li>
# </ul>
# </li>
# <li class="dropdown" id="nav-locations">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Locations</a>
# <ul class="dropdown-menu" id="resources-menu">
# <li>
# <a href="/en-US/locations/directory" rel="nofollow">Worldwide Directory</a>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle" href="/en-US/maps#001" rel="nofollow">Maps</a>
# </li>
# <li><a href="/en-US/locations/contacts" rel="nofollow">Contacts</a></li>
# </ul>
# </li>
# <li class="dropdown" id="nav-special-sites">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Special Sites</a>
# <ul class="dropdown-menu" id="special-sites-menu">
# <li><a href="/os/" target="_blank">For Old Students</a></li>
# <li><a href="http://www.executive.dhamma.org/" target="_blank">Vipassana for Executives</a></li>
# <li>
# <a href="http://www.prison.dhamma.org/" target="_blank">Vipassana for Prisons</a>
# </li>
# <li>
# <a href="http://www.children.dhamma.org/" target="_blank">Children's Courses</a>
# </li>
# <li><a href="https://www.dhamma.org/en/vri.htm" target="_blank">Vipassana Research Institute</a></li>
# <li><a href="https://www.dhamma.org/en/global.htm" target="_blank">Global Vipassana Pagoda</a></li>
# <li><a href="/en-US/about/mini_anapana">Mini Anapana Meditation</a></li>
# <li><a href="/en-US/about/more_language_sites">More Language Sites</a></li>
# </ul>
# </li>
# <li id="nav-language">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">
# <i class="glyphicon glyphicon-globe"></i> U.S. English
# </a>
# <ul class="dropdown-menu" id="select-language-list">
# <li><a href="/bg/courses/search">български</a></li>
# <li><a href="/cs/courses/search">čeština</a></li>
# <li><a href="/de/courses/search">Deutsch</a></li>
# <li><a href="/el/courses/search">Ελληνικά</a></li>
# <li><a href="/en/courses/search">English</a></li>
# <li><a href="/en-US/courses/search">U.S. English</a></li>
# <li><a href="/es/courses/search">Español</a></li>
# <li><a href="/fa/courses/search">فارسی</a></li>
# <li><a href="/fi/courses/search">Suomi</a></li>
# <li><a href="/fr/courses/search">Français</a></li>
# <li><a href="/fr-CA/courses/search">Français canadien</a></li>
# <li><a href="/gu/courses/search">ગુજરાતી</a></li>
# <li><a href="/he/courses/search">עברית</a></li>
# <li><a href="/hi/courses/search">हिन्दी</a></li>
# <li><a href="/hu/courses/search">Magyar</a></li>
# <li><a href="/id/courses/search">Bahasa Indonesia</a></li>
# <li><a href="/it/courses/search">Italiano</a></li>
# <li><a href="/it-CH/courses/search">Svizzero Italiano</a></li>
# <li><a href="/ja/courses/search">日本語</a></li>
# <li><a href="/km/courses/search">ភាសាខ្មែរ</a></li>
# <li><a href="/ko/courses/search">한국어</a></li>
# <li><a href="/lt/courses/search">Lietuvių</a></li>
# <li><a href="/lv/courses/search">Latviešu</a></li>
# <li><a href="/mk/courses/search">македонски</a></li>
# <li><a href="/mr/courses/search">मराठी</a></li>
# <li><a href="/ne/courses/search">नेपाली</a></li>
# <li><a href="/nl/courses/search">Nederlands</a></li>
# <li><a href="/pl/courses/search">Polski</a></li>
# <li><a href="/pt/courses/search">Português</a></li>
# <li><a href="/pt-BR/courses/search">Português do Brasil</a></li>
# <li><a href="/ro/courses/search">Română</a></li>
# <li><a href="/ru/courses/search">русский</a></li>
# <li><a href="/si/courses/search">සිංහල</a></li>
# <li><a href="/sr/courses/search">Српски</a></li>
# <li><a href="/sv/courses/search">Svenska</a></li>
# <li><a href="/ta/courses/search">தமிழ்</a></li>
# <li><a href="/te/courses/search">తెలుగు</a></li>
# <li><a href="/th/courses/search">ไทย</a></li>
# <li><a href="/tr/courses/search">Türkçe</a></li>
# <li><a href="/vi/courses/search">Tiếng Việt</a></li>
# <li><a href="/zh-HANS/courses/search">简体字</a></li>
# <li><a href="/zh-HANT/courses/search">繁體字</a></li>
# <li>
# <p>Translations are in progress. Some pages may have a mix of your selected language and English.</p>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </nav>
# </div>, <div class="container-fluid">
# <button class="navbar-toggle" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <div class="navbar-collapse-container">
# <div class="navbar-collapse">
# <ul class="nav navbar-nav">
# <li id="nav-home">
# <a class="dropdown-toggle" data-original-title="Home" href="/en-US/index" title="">
# <i class="glyphicon glyphicon-home"></i>
# </a> </li>
# <li class="dropdown" id="nav-about">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">About</a>
# <ul class="dropdown-menu" id="about-menu">
# <li><a href="/en-US/about/vipassana">What is Vipassana?</a></li>
# <li><a href="/en-US/about/goenka">Mr. S.N. Goenka</a></li>
# <li><a href="/en-US/about/art">The Art of Living: Vipassana Meditation</a></li>
# <li><a href="/en-US/about/code">The Code of Discipline</a></li>
# <li><a href="/en-US/about/qanda">Questions &amp; Answers About the Technique of Vipassana Meditation</a></li>
# </ul>
# </li>
# <li class="dropdown" id="nav-courses">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Courses</a>
# <ul class="dropdown-menu" id="courses-menu">
# <li>
# <a href="/en-US/courses/search" rel="nofollow">Search</a>
# </li>
# <li class="dropdown">
# <a href="/en-US/courses/glossary" rel="nofollow">Glossary</a>
# </li>
# </ul>
# </li>
# <li class="dropdown" id="nav-locations">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Locations</a>
# <ul class="dropdown-menu" id="resources-menu">
# <li>
# <a href="/en-US/locations/directory" rel="nofollow">Worldwide Directory</a>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle" href="/en-US/maps#001" rel="nofollow">Maps</a>
# </li>
# <li><a href="/en-US/locations/contacts" rel="nofollow">Contacts</a></li>
# </ul>
# </li>
# <li class="dropdown" id="nav-special-sites">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Special Sites</a>
# <ul class="dropdown-menu" id="special-sites-menu">
# <li><a href="/os/" target="_blank">For Old Students</a></li>
# <li><a href="http://www.executive.dhamma.org/" target="_blank">Vipassana for Executives</a></li>
# <li>
# <a href="http://www.prison.dhamma.org/" target="_blank">Vipassana for Prisons</a>
# </li>
# <li>
# <a href="http://www.children.dhamma.org/" target="_blank">Children's Courses</a>
# </li>
# <li><a href="https://www.dhamma.org/en/vri.htm" target="_blank">Vipassana Research Institute</a></li>
# <li><a href="https://www.dhamma.org/en/global.htm" target="_blank">Global Vipassana Pagoda</a></li>
# <li><a href="/en-US/about/mini_anapana">Mini Anapana Meditation</a></li>
# <li><a href="/en-US/about/more_language_sites">More Language Sites</a></li>
# </ul>
# </li>
# <li id="nav-language">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">
# <i class="glyphicon glyphicon-globe"></i> U.S. English
# </a>
# <ul class="dropdown-menu" id="select-language-list">
# <li><a href="/bg/courses/search">български</a></li>
# <li><a href="/cs/courses/search">čeština</a></li>
# <li><a href="/de/courses/search">Deutsch</a></li>
# <li><a href="/el/courses/search">Ελληνικά</a></li>
# <li><a href="/en/courses/search">English</a></li>
# <li><a href="/en-US/courses/search">U.S. English</a></li>
# <li><a href="/es/courses/search">Español</a></li>
# <li><a href="/fa/courses/search">فارسی</a></li>
# <li><a href="/fi/courses/search">Suomi</a></li>
# <li><a href="/fr/courses/search">Français</a></li>
# <li><a href="/fr-CA/courses/search">Français canadien</a></li>
# <li><a href="/gu/courses/search">ગુજરાતી</a></li>
# <li><a href="/he/courses/search">עברית</a></li>
# <li><a href="/hi/courses/search">हिन्दी</a></li>
# <li><a href="/hu/courses/search">Magyar</a></li>
# <li><a href="/id/courses/search">Bahasa Indonesia</a></li>
# <li><a href="/it/courses/search">Italiano</a></li>
# <li><a href="/it-CH/courses/search">Svizzero Italiano</a></li>
# <li><a href="/ja/courses/search">日本語</a></li>
# <li><a href="/km/courses/search">ភាសាខ្មែរ</a></li>
# <li><a href="/ko/courses/search">한국어</a></li>
# <li><a href="/lt/courses/search">Lietuvių</a></li>
# <li><a href="/lv/courses/search">Latviešu</a></li>
# <li><a href="/mk/courses/search">македонски</a></li>
# <li><a href="/mr/courses/search">मराठी</a></li>
# <li><a href="/ne/courses/search">नेपाली</a></li>
# <li><a href="/nl/courses/search">Nederlands</a></li>
# <li><a href="/pl/courses/search">Polski</a></li>
# <li><a href="/pt/courses/search">Português</a></li>
# <li><a href="/pt-BR/courses/search">Português do Brasil</a></li>
# <li><a href="/ro/courses/search">Română</a></li>
# <li><a href="/ru/courses/search">русский</a></li>
# <li><a href="/si/courses/search">සිංහල</a></li>
# <li><a href="/sr/courses/search">Српски</a></li>
# <li><a href="/sv/courses/search">Svenska</a></li>
# <li><a href="/ta/courses/search">தமிழ்</a></li>
# <li><a href="/te/courses/search">తెలుగు</a></li>
# <li><a href="/th/courses/search">ไทย</a></li>
# <li><a href="/tr/courses/search">Türkçe</a></li>
# <li><a href="/vi/courses/search">Tiếng Việt</a></li>
# <li><a href="/zh-HANS/courses/search">简体字</a></li>
# <li><a href="/zh-HANT/courses/search">繁體字</a></li>
# <li>
# <p>Translations are in progress. Some pages may have a mix of your selected language and English.</p>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </div>, <div class="navbar-collapse-container">
# <div class="navbar-collapse">
# <ul class="nav navbar-nav">
# <li id="nav-home">
# <a class="dropdown-toggle" data-original-title="Home" href="/en-US/index" title="">
# <i class="glyphicon glyphicon-home"></i>
# </a> </li>
# <li class="dropdown" id="nav-about">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">About</a>
# <ul class="dropdown-menu" id="about-menu">
# <li><a href="/en-US/about/vipassana">What is Vipassana?</a></li>
# <li><a href="/en-US/about/goenka">Mr. S.N. Goenka</a></li>
# <li><a href="/en-US/about/art">The Art of Living: Vipassana Meditation</a></li>
# <li><a href="/en-US/about/code">The Code of Discipline</a></li>
# <li><a href="/en-US/about/qanda">Questions &amp; Answers About the Technique of Vipassana Meditation</a></li>
# </ul>
# </li>
# <li class="dropdown" id="nav-courses">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Courses</a>
# <ul class="dropdown-menu" id="courses-menu">
# <li>
# <a href="/en-US/courses/search" rel="nofollow">Search</a>
# </li>
# <li class="dropdown">
# <a href="/en-US/courses/glossary" rel="nofollow">Glossary</a>
# </li>
# </ul>
# </li>
# <li class="dropdown" id="nav-locations">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Locations</a>
# <ul class="dropdown-menu" id="resources-menu">
# <li>
# <a href="/en-US/locations/directory" rel="nofollow">Worldwide Directory</a>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle" href="/en-US/maps#001" rel="nofollow">Maps</a>
# </li>
# <li><a href="/en-US/locations/contacts" rel="nofollow">Contacts</a></li>
# </ul>
# </li>
# <li class="dropdown" id="nav-special-sites">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Special Sites</a>
# <ul class="dropdown-menu" id="special-sites-menu">
# <li><a href="/os/" target="_blank">For Old Students</a></li>
# <li><a href="http://www.executive.dhamma.org/" target="_blank">Vipassana for Executives</a></li>
# <li>
# <a href="http://www.prison.dhamma.org/" target="_blank">Vipassana for Prisons</a>
# </li>
# <li>
# <a href="http://www.children.dhamma.org/" target="_blank">Children's Courses</a>
# </li>
# <li><a href="https://www.dhamma.org/en/vri.htm" target="_blank">Vipassana Research Institute</a></li>
# <li><a href="https://www.dhamma.org/en/global.htm" target="_blank">Global Vipassana Pagoda</a></li>
# <li><a href="/en-US/about/mini_anapana">Mini Anapana Meditation</a></li>
# <li><a href="/en-US/about/more_language_sites">More Language Sites</a></li>
# </ul>
# </li>
# <li id="nav-language">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">
# <i class="glyphicon glyphicon-globe"></i> U.S. English
# </a>
# <ul class="dropdown-menu" id="select-language-list">
# <li><a href="/bg/courses/search">български</a></li>
# <li><a href="/cs/courses/search">čeština</a></li>
# <li><a href="/de/courses/search">Deutsch</a></li>
# <li><a href="/el/courses/search">Ελληνικά</a></li>
# <li><a href="/en/courses/search">English</a></li>
# <li><a href="/en-US/courses/search">U.S. English</a></li>
# <li><a href="/es/courses/search">Español</a></li>
# <li><a href="/fa/courses/search">فارسی</a></li>
# <li><a href="/fi/courses/search">Suomi</a></li>
# <li><a href="/fr/courses/search">Français</a></li>
# <li><a href="/fr-CA/courses/search">Français canadien</a></li>
# <li><a href="/gu/courses/search">ગુજરાતી</a></li>
# <li><a href="/he/courses/search">עברית</a></li>
# <li><a href="/hi/courses/search">हिन्दी</a></li>
# <li><a href="/hu/courses/search">Magyar</a></li>
# <li><a href="/id/courses/search">Bahasa Indonesia</a></li>
# <li><a href="/it/courses/search">Italiano</a></li>
# <li><a href="/it-CH/courses/search">Svizzero Italiano</a></li>
# <li><a href="/ja/courses/search">日本語</a></li>
# <li><a href="/km/courses/search">ភាសាខ្មែរ</a></li>
# <li><a href="/ko/courses/search">한국어</a></li>
# <li><a href="/lt/courses/search">Lietuvių</a></li>
# <li><a href="/lv/courses/search">Latviešu</a></li>
# <li><a href="/mk/courses/search">македонски</a></li>
# <li><a href="/mr/courses/search">मराठी</a></li>
# <li><a href="/ne/courses/search">नेपाली</a></li>
# <li><a href="/nl/courses/search">Nederlands</a></li>
# <li><a href="/pl/courses/search">Polski</a></li>
# <li><a href="/pt/courses/search">Português</a></li>
# <li><a href="/pt-BR/courses/search">Português do Brasil</a></li>
# <li><a href="/ro/courses/search">Română</a></li>
# <li><a href="/ru/courses/search">русский</a></li>
# <li><a href="/si/courses/search">සිංහල</a></li>
# <li><a href="/sr/courses/search">Српски</a></li>
# <li><a href="/sv/courses/search">Svenska</a></li>
# <li><a href="/ta/courses/search">தமிழ்</a></li>
# <li><a href="/te/courses/search">తెలుగు</a></li>
# <li><a href="/th/courses/search">ไทย</a></li>
# <li><a href="/tr/courses/search">Türkçe</a></li>
# <li><a href="/vi/courses/search">Tiếng Việt</a></li>
# <li><a href="/zh-HANS/courses/search">简体字</a></li>
# <li><a href="/zh-HANT/courses/search">繁體字</a></li>
# <li>
# <p>Translations are in progress. Some pages may have a mix of your selected language and English.</p>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>, <div class="navbar-collapse">
# <ul class="nav navbar-nav">
# <li id="nav-home">
# <a class="dropdown-toggle" data-original-title="Home" href="/en-US/index" title="">
# <i class="glyphicon glyphicon-home"></i>
# </a> </li>
# <li class="dropdown" id="nav-about">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">About</a>
# <ul class="dropdown-menu" id="about-menu">
# <li><a href="/en-US/about/vipassana">What is Vipassana?</a></li>
# <li><a href="/en-US/about/goenka">Mr. S.N. Goenka</a></li>
# <li><a href="/en-US/about/art">The Art of Living: Vipassana Meditation</a></li>
# <li><a href="/en-US/about/code">The Code of Discipline</a></li>
# <li><a href="/en-US/about/qanda">Questions &amp; Answers About the Technique of Vipassana Meditation</a></li>
# </ul>
# </li>
# <li class="dropdown" id="nav-courses">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Courses</a>
# <ul class="dropdown-menu" id="courses-menu">
# <li>
# <a href="/en-US/courses/search" rel="nofollow">Search</a>
# </li>
# <li class="dropdown">
# <a href="/en-US/courses/glossary" rel="nofollow">Glossary</a>
# </li>
# </ul>
# </li>
# <li class="dropdown" id="nav-locations">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Locations</a>
# <ul class="dropdown-menu" id="resources-menu">
# <li>
# <a href="/en-US/locations/directory" rel="nofollow">Worldwide Directory</a>
# </li>
# <li class="dropdown">
# <a class="dropdown-toggle" href="/en-US/maps#001" rel="nofollow">Maps</a>
# </li>
# <li><a href="/en-US/locations/contacts" rel="nofollow">Contacts</a></li>
# </ul>
# </li>
# <li class="dropdown" id="nav-special-sites">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">Special Sites</a>
# <ul class="dropdown-menu" id="special-sites-menu">
# <li><a href="/os/" target="_blank">For Old Students</a></li>
# <li><a href="http://www.executive.dhamma.org/" target="_blank">Vipassana for Executives</a></li>
# <li>
# <a href="http://www.prison.dhamma.org/" target="_blank">Vipassana for Prisons</a>
# </li>
# <li>
# <a href="http://www.children.dhamma.org/" target="_blank">Children's Courses</a>
# </li>
# <li><a href="https://www.dhamma.org/en/vri.htm" target="_blank">Vipassana Research Institute</a></li>
# <li><a href="https://www.dhamma.org/en/global.htm" target="_blank">Global Vipassana Pagoda</a></li>
# <li><a href="/en-US/about/mini_anapana">Mini Anapana Meditation</a></li>
# <li><a href="/en-US/about/more_language_sites">More Language Sites</a></li>
# </ul>
# </li>
# <li id="nav-language">
# <a class="dropdown-toggle" data-toggle="dropdown" href="#">
# <i class="glyphicon glyphicon-globe"></i> U.S. English
# </a>
# <ul class="dropdown-menu" id="select-language-list">
# <li><a href="/bg/courses/search">български</a></li>
# <li><a href="/cs/courses/search">čeština</a></li>
# <li><a href="/de/courses/search">Deutsch</a></li>
# <li><a href="/el/courses/search">Ελληνικά</a></li>
# <li><a href="/en/courses/search">English</a></li>
# <li><a href="/en-US/courses/search">U.S. English</a></li>
# <li><a href="/es/courses/search">Español</a></li>
# <li><a href="/fa/courses/search">فارسی</a></li>
# <li><a href="/fi/courses/search">Suomi</a></li>
# <li><a href="/fr/courses/search">Français</a></li>
# <li><a href="/fr-CA/courses/search">Français canadien</a></li>
# <li><a href="/gu/courses/search">ગુજરાતી</a></li>
# <li><a href="/he/courses/search">עברית</a></li>
# <li><a href="/hi/courses/search">हिन्दी</a></li>
# <li><a href="/hu/courses/search">Magyar</a></li>
# <li><a href="/id/courses/search">Bahasa Indonesia</a></li>
# <li><a href="/it/courses/search">Italiano</a></li>
# <li><a href="/it-CH/courses/search">Svizzero Italiano</a></li>
# <li><a href="/ja/courses/search">日本語</a></li>
# <li><a href="/km/courses/search">ភាសាខ្មែរ</a></li>
# <li><a href="/ko/courses/search">한국어</a></li>
# <li><a href="/lt/courses/search">Lietuvių</a></li>
# <li><a href="/lv/courses/search">Latviešu</a></li>
# <li><a href="/mk/courses/search">македонски</a></li>
# <li><a href="/mr/courses/search">मराठी</a></li>
# <li><a href="/ne/courses/search">नेपाली</a></li>
# <li><a href="/nl/courses/search">Nederlands</a></li>
# <li><a href="/pl/courses/search">Polski</a></li>
# <li><a href="/pt/courses/search">Português</a></li>
# <li><a href="/pt-BR/courses/search">Português do Brasil</a></li>
# <li><a href="/ro/courses/search">Română</a></li>
# <li><a href="/ru/courses/search">русский</a></li>
# <li><a href="/si/courses/search">සිංහල</a></li>
# <li><a href="/sr/courses/search">Српски</a></li>
# <li><a href="/sv/courses/search">Svenska</a></li>
# <li><a href="/ta/courses/search">தமிழ்</a></li>
# <li><a href="/te/courses/search">తెలుగు</a></li>
# <li><a href="/th/courses/search">ไทย</a></li>
# <li><a href="/tr/courses/search">Türkçe</a></li>
# <li><a href="/vi/courses/search">Tiếng Việt</a></li>
# <li><a href="/zh-HANS/courses/search">简体字</a></li>
# <li><a href="/zh-HANT/courses/search">繁體字</a></li>
# <li>
# <p>Translations are in progress. Some pages may have a mix of your selected language and English.</p>
# </li>
# </ul>
# </li>
# </ul>
# </div>, <div class="container" id="container">
# <div id="content">
# <section id="top">
# <div id="header-container">
# <header id="page-header">
# <div class="hidden-xs">
# <div class="text-right" id="header-left">
# <h1>Vipassana</h1>
# <p>As taught by S.N. Goenka</p>
# </div>
# <div id="wheel">
# <img alt="Aniwheel" src="/assets/aniwheel-a87352d07ff79e922e5afbc8775f603b.gif"/>
# </div>
# <div class="text-left" id="header-right">
# <h1>Meditation</h1>
# <p>in the tradition of Sayagyi U Ba Khin</p>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="visible-xs">
# <div id="wheel">
# <a href="/en-US/index">
# <img src="/assets/aniwheel-a87352d07ff79e922e5afbc8775f603b.gif" width="100%"/>
# </a> </div>
# <a href="/en-US/index">
# <h1>Vipassana Meditation</h1>
# </a> <p class="subhead">As taught by S.N. Goenka<br/>in the tradition of Sayagyi U Ba Khin</p>
# </div>
# </header>
# </div>
# <div class="hidden-xs">
# <ul class="nav nav-pills" id="navbar">
# <li id="nav-home">
# <a class="dropdown-toggle" data-original-title="Home" href="/en-US/index" title="">
# <i class="glyphicon glyphicon-home"></i>
# </a> </li>
# <li class=" dropdown" id="nav-about">
# <a class="dropdown-toggle" href="/en-US/about/vipassana">About</a>
# <ul class="dropdown-menu" id="about-menu" style="left: -38px;">
# <li><a href="/en-US/about/vipassana">What is Vipassana?</a></li>
# <li><a href="/en-US/about/goenka">Mr. S.N. Goenka</a></li>
# <li><a href="/en-US/about/art">The Art of Living: Vipassana Meditation</a></li>
# <li><a href="/en-US/about/code">The Code of Discipline</a></li>
# <li><a href="/en-US/about/qanda">Questions &amp; Answers About the Technique of Vipassana Meditation</a></li>
# </ul>
# </li>
# <li class="dropdown" id="nav-courses">
# <a class="dropdown-toggle" href="/en-US/courses/search" rel="nofollow">Courses</a>
# <ul class="dropdown-menu" id="courses-menu" style="left: -38px;">
# <li>
# <a href="/en-US/courses/search" rel="nofollow">Search</a>
# </li>
# <li class="dropdown">
# <a href="/en-US/courses/glossary" rel="nofollow">Glossary</a>
# </li>
# </ul>
# </li>
# <li class="dropdown" id="nav-locations">
# <a href="/en-US/locations/directory" rel="nofollow">Locations</a>
# <ul class="dropdown-menu" id="resources-menu" style="left: -37.5px;">
# <li>
# <a href="/en-US/locations/directory" rel="nofollow">Worldwide Directory</a>
# </li>
# <li class="dropdown">
# <a href="/en-US/maps#001" rel="nofollow">Maps</a>
# </li>
# <li><a href="/en-US/locations/contacts" rel="nofollow">Contacts</a></li>
# </ul>
# </li>
# <li class="dropdown" id="nav-special-sites">
# <a class="dropdown-toggle" href="#">Special Sites</a>
# <ul class="dropdown-menu" id="special-sites-menu" style="left: -34px;">
# <li><a href="/os/" target="_blank">For Old Students</a></li>
# <li><a href="http://www.executive.dhamma.org/" target="_blank">Vipassana for Executives</a></li>
# <li>
# <a href="http://www.prison.dhamma.org/" target="_blank">Vipassana for Prisons</a>
# </li>
# <li>
# <a href="http://www.children.dhamma.org/" target="_blank">Children's Courses</a>
# </li>
# <li><a href="https://www.dhamma.org/en/vri.htm" target="_blank">Vipassana Research Institute</a></li>
# <li><a href="https://www.dhamma.org/en/global.htm" target="_blank">Global Vipassana Pagoda</a></li>
# <li><a href="/en-US/about/mini_anapana">Mini Anapana Meditation</a></li>
# <li><a href="/en-US/about/more_language_sites">More Language Sites</a></li>
# </ul>
# </li>
# <li id="nav-language">
# <a href="#set-language">
# <i class="glyphicon glyphicon-globe"></i> U.S. English
# </a>
# <div class="panel panel-default" id="select-language">
# <div class="panel-body">
# <h3>Select Language</h3>
# <ul id="select-language-list">
# <li><a href="/bg/courses/search">български</a></li>
# <li><a href="/cs/courses/search">čeština</a></li>
# <li><a href="/de/courses/search">Deutsch</a></li>
# <li><a href="/el/courses/search">Ελληνικά</a></li>
# <li><a href="/en/courses/search">English</a></li>
# <li><a href="/en-US/courses/search">U.S. English</a></li>
# <li><a href="/es/courses/search">Español</a></li>
# <li><a href="/fa/courses/search">فارسی</a></li>
# <li><a href="/fi/courses/search">Suomi</a></li>
# <li><a href="/fr/courses/search">Français</a></li>
# <li><a href="/fr-CA/courses/search">Français canadien</a></li>
# </ul><ul>
# <li><a href="/gu/courses/search">ગુજરાતી</a></li>
# <li><a href="/he/courses/search">עברית</a></li>
# <li><a href="/hi/courses/search">हिन्दी</a></li>
# <li><a href="/hu/courses/search">Magyar</a></li>
# <li><a href="/id/courses/search">Bahasa Indonesia</a></li>
# <li><a href="/it/courses/search">Italiano</a></li>
# <li><a href="/it-CH/courses/search">Svizzero Italiano</a></li>
# <li><a href="/ja/courses/search">日本語</a></li>
# <li><a href="/km/courses/search">ភាសាខ្មែរ</a></li>
# <li><a href="/ko/courses/search">한국어</a></li>
# <li><a href="/lt/courses/search">Lietuvių</a></li>
# </ul><ul>
# <li><a href="/lv/courses/search">Latviešu</a></li>
# <li><a href="/mk/courses/search">македонски</a></li>
# <li><a href="/mr/courses/search">मराठी</a></li>
# <li><a href="/ne/courses/search">नेपाली</a></li>
# <li><a href="/nl/courses/search">Nederlands</a></li>
# <li><a href="/pl/courses/search">Polski</a></li>
# <li><a href="/pt/courses/search">Português</a></li>
# <li><a href="/pt-BR/courses/search">Português do Brasil</a></li>
# <li><a href="/ro/courses/search">Română</a></li>
# <li><a href="/ru/courses/search">русский</a></li>
# </ul><ul>
# <li><a href="/si/courses/search">සිංහල</a></li>
# <li><a href="/sr/courses/search">Српски</a></li>
# <li><a href="/sv/courses/search">Svenska</a></li>
# <li><a href="/ta/courses/search">தமிழ்</a></li>
# <li><a href="/te/courses/search">తెలుగు</a></li>
# <li><a href="/th/courses/search">ไทย</a></li>
# <li><a href="/tr/courses/search">Türkçe</a></li>
# <li><a href="/vi/courses/search">Tiếng Việt</a></li>
# <li><a href="/zh-HANS/courses/search">简体字</a></li>
# <li><a href="/zh-HANT/courses/search">繁體字</a></li>
# </ul>
# <div class="clearfix"></div>
# <hr/>
# <p>Translations are in progress. Some pages may have a mix of your selected language and English.</p>
# <br/>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </section>
# <section id="main">
# <br/>
# <section class="tabbed-header">
# <h2>
# Courses
# <small class="icon hidden-xs"><a data-content='&lt;span class="notes-title"&gt;To find a course:&lt;/span&gt; &amp;nbsp;&amp;nbsp;&amp;nbsp; 1. (Optional) Enter one or more search criteria in the boxes &amp;nbsp;&amp;nbsp;&amp;nbsp; 2. Click the blue search button.&lt;br /&gt;
# &lt;br type="_moz" /&gt;&lt;hr /&gt;&lt;div&gt;
# 	How to locate and apply for courses:  &lt;/div&gt;
# &lt;div&gt;
# 	&lt;ul&gt;
# 		&lt;li&gt;
# 			Select an applicable tab, refine the search options by specifying one or more values per box (re-click the same box to specify additional values) and press the search button&lt;/li&gt;
# 		&lt;li&gt;
# 			Find a suitable course from the list of available courses and click the Apply button to access the online application form in the language of your choice (only the top 100 results are returned; if you do not find a suitable course from the returned result set then refine the search options further and reissue the search)&lt;/li&gt;
# 		&lt;li&gt;
# 			Read carefully the Introduction to the Technique and Code of Discipline which you will be asked to follow during your course.  Fully and completely fill out all the sections of application form and submit it.  An application is required to register for all courses.&lt;/li&gt;
# 		&lt;li&gt;
# 			Await notification.  All correspondence will be through e-mail if you give an e-mail address in your application. Due to the large volume of applications, it may take several weeks before receiving notification.&lt;/li&gt;
# 		&lt;li&gt;
# 			If your application is accepted then we require you to confirm you will be attending in order to secure your place in the course.&lt;/li&gt;
# 	&lt;/ul&gt;
# &lt;/div&gt;' data-html="true" data-original-title="" data-placement="left" data-toggle="popover" href="#" title=""><i class="glyphicon glyphicon-question-sign"></i></a></small>
# </h2>
# <div id="course-search">
# <ul class="hidden-xs nav nav-tabs nav-quarters" id="student-type-select">
# <li class="active" data-bind="css: {active: current_state() == 'NewStudents'}, click: search_new_students">
# <a class="new-student" href="#">For New Students</a></li>
# <li class="" data-bind="css: {active: current_state() == 'OldStudents'}, click: search_old_students">
# <a class="old-student" href="#">For Old Students</a></li>
# <li class="" data-bind="css: {active: current_state() == 'Children'}, click: search_children">
# <a class="child" href="#">For Children/Teens</a></li>
# <li class="" data-bind="css: {active: current_state() == 'Executives'}, click: search_executives">
# <a class="executive" href="#">For Executives</a></li>
# </ul>
# <div class="search-panel" id="course-search-panel">
# <div id="search-panel-form">
# <div class="row">
# <div class="col-sm-10" id="search-panel-form-inputs">
# <div class="row">
# <div class="col-sm-4 visible-xs form-group">
# <select class="form-control" data-bind="event: { change: change_search_mode }" id="student-type-select-mobile">
# <option value="NewStudents">For New Students</option>
# <option value="OldStudents">For Old Students</option>
# <option value="Children">For Children/Teens</option>
# <option value="Executives">For Executives</option>
# </select>
# </div>
# <div class="col-sm-4 form-group" data-bind="css: {'has-error': dates_invalid}">
# <input class="form-control date" data-bind="daterangepicker: {separator: ' \u2014 ', arrows: true, showDropdowns: true,
#           format: date_format(), locale: { applyLabel: 'Confirm',
#           cancelLabel: 'Cancel', fromLabel: 'from',
#           toLabel: 'to' }}, value: search_daterange" id="course-search-date-range" placeholder="Select Date Range"/>
# </div>
# <div class="col-sm-4">
# <div class="form-group">
# <div class="select2-container select2-container-multi form-control" id="s2id_loc_search"><ul class="select2-choices"> <li class="select2-search-field"> <label class="select2-offscreen" for="s2id_autogen1"></label> <input autocapitalize="off" autocomplete="off" autocorrect="off" class="select2-input select2-default" id="s2id_autogen1" placeholder="" spellcheck="false" style="width: 222px;" type="text"/> </li></ul><div class="select2-drop select2-drop-multi select2-display-none"> <ul class="select2-results"> <li class="select2-no-results">No matches found</li><li class="select2-no-results">No matches found</li><li class="select2-no-results">No matches found</li></ul></div></div><input class="form-control" data-bind="select2ValueUpdate: search_region, select2: select2_config_region()" id="loc_search" placeholder="State/Province, Country, Region" style="display: none;" tabindex="-1" type="hidden" value=""/>
# </div>
# </div>
# <div class="col-sm-4">
# <div class="select2-container select2-container-multi form-control" id="s2id_language-filter"><ul class="select2-choices"> <li class="select2-search-field"> <label class="select2-offscreen" for="s2id_autogen2"></label> <input autocapitalize="off" autocomplete="off" autocorrect="off" class="select2-input select2-default" id="s2id_autogen2" placeholder="" spellcheck="false" style="width: 222px;" type="text"/> </li></ul><div class="select2-drop select2-drop-multi select2-display-none"> <ul class="select2-results"> <li class="select2-no-results">No matches found</li><li class="select2-no-results">No matches found</li></ul></div></div><select class="form-control" data-bind="select2: {placeholder: 'Select Course Language'}, options: instruction_languages, optionsText: 'description', optionsValue: 'iso_code', selectedOptions: search_languages" id="language-filter" multiple="" style="display: none;" tabindex="-1"><option value="af">Afrikaans</option><option value="am">Amharic</option><option value="ar">Arabic</option><option value="bn">Bengali</option><option value="bg">Bulgarian</option><option value="my">Burmese</option><option value="yue">Cantonese</option><option value="cs">Czech</option><option value="da">Danish</option><option value="nl">Dutch</option><option value="en">English</option><option value="fi">Finnish</option><option value="fr">French</option><option value="de">German</option><option value="el">Greek</option><option value="gu">Gujarati</option><option value="hak">Hakka</option><option value="he">Hebrew</option><option value="hi">Hindi</option><option value="hu">Hungarian</option><option value="id">Indonesian</option><option value="it">Italian</option><option value="ja">Japanese</option><option value="kn">Kannada</option><option value="km">Khmer</option><option value="ko">Korean</option><option value="lv">Latvian</option><option value="lt">Lithuanian</option><option value="ml">Malayalam</option><option value="cmn">Mandarin</option><option value="mr">Marathi</option><option value="mon">Mon</option><option value="mn">Mongolian</option><option value="ne">Nepali</option><option value="new">Newari</option><option value="no">Norwegian</option><option value="fa">Persian (Farsi)</option><option value="pl">Polish</option><option value="pt">Portuguese</option><option value="pa">Punjabi</option><option value="ro">Romanian</option><option value="ru">Russian</option><option value="sr">Serbian</option><option value="hbs">Serbo-Croatian</option><option value="shn">Shan</option><option value="si">Sinhala</option><option value="sl">Slovenian</option><option value="es">Spanish</option><option value="sw">Swahili</option><option value="sv">Swedish</option><option value="tl">Tagalog</option><option value="ta">Tamil</option><option value="te">Telugu</option><option value="th">Thai</option><option value="tr">Turkish</option><option value="vi">Vietnamese</option>
# </select>
# </div>
# </div>
# <div class="row">
# <!-- ko if: showAdvancedOptions --><!-- /ko -->
# <!-- ko if: current_state() == 'OldStudents' --><!-- /ko -->
# <div class="col-sm-4">
# </div>
# </div>
# </div>
# <div class="col-sm-2">
# <a class="btn btn-apply center" data-bind="click: performSearch" href="/search" style="width:100%;">
# <i class="glyphicon glyphicon-search"></i></a>
# <!-- ko if: share() --><!-- /ko -->
# </div>
# </div>
# </div>
# <div class="search-toolbar btn-toolbar" id="course-list-setting">
# <!-- ko if: results_on_search --><!-- /ko -->
# </div>
# </div>
# </div>
# </section>
# <section data-bind="template: current_view" id="course-search-results">
# <!-- Template for rendering list of results -->
# <!-- ko foreach: {data: courses, afterRender: postprocess_course} --><!-- /ko -->
# </section>
# <!-- ko if: results_on_search --><!-- /ko -->
# <!-- ko if: searched --><!-- /ko -->
# <div id="course-search-instructions">
# <!-- ko if: current_state() == 'NewStudents' -->
# <p>
# <a name="10-Day"></a> <span class="notes-title">10-day Courses</span> are an introductory course to Vipassana Meditation where the technique is taught step-by-step each day. The courses begin after a 2 - 4 pm registration period and orientation, followed by 10 full days of meditation, and end the morning of the 11th day by 7:30 am.</p>
# <!-- /ko -->
# <!-- ko if: current_state() == 'OldStudents' --><!-- /ko -->
# <!-- ko if: current_state() == 'Children' --><!-- /ko -->
# <!-- ko if: current_state() == 'Executives' --><!-- /ko -->
# </div>
# <script id="course_status" type="text/html">
#   &lt;div data-bind="foreach: status"&gt;
# &lt;span data-bind="html: status_text, classes: status_classes"&gt;&lt;/span&gt;
# &lt;/div&gt;
#
# </script>
# <div id="location-modal-container"></div>
# </section>
# </div>
# <div id="footer">
# <hr/>
# <p>
# Dhamma.org
# </p>
# <p>
# <a href="/en-US/about/privacy">Privacy Policy</a>
# |
# <a href="mailto:webmaster@dhamma.org">Email Webmaster</a>
# </p>
# <p>
# <a href="https://itunes.apple.com/us/app/dhamma-org/id1127952631?mt=8"><img alt="App store us uk" src="/assets/app-store-us-uk-475b9d8be87e34a116c3763a3640c26f.svg" width="135"/></a>
# <a href="https://play.google.com/store/apps/details?id=org.dhamma"><img alt="Play store badge" src="/assets/play-store-badge-fd9ac7cfac52af3d94574d52ae0f29d9.png" width="155"/></a> </p>
# <p>
# <a href="/en-US/about/mobile-app">Dhamma.org Mobile App</a>
# </p>
# </div>
# </div>, <div id="content">
# <section id="top">
# <div id="header-container">
# <header id="page-header">
# <div class="hidden-xs">
# <div class="text-right" id="header-left">
# <h1>Vipassana</h1>
# <p>As taught by S.N. Goenka</p>
# </div>
# <div id="wheel">
# <img alt="Aniwheel" src="/assets/aniwheel-a87352d07ff79e922e5afbc8775f603b.gif"/>
# </div>
# <div class="text-left" id="header-right">
# <h1>Meditation</h1>
# <p>in the tradition of Sayagyi U Ba Khin</p>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="visible-xs">
# <div id="wheel">
# <a href="/en-US/index">
# <img src="/assets/aniwheel-a87352d07ff79e922e5afbc8775f603b.gif" width="100%"/>
# </a> </div>
# <a href="/en-US/index">
# <h1>Vipassana Meditation</h1>
# </a> <p class="subhead">As taught by S.N. Goenka<br/>in the tradition of Sayagyi U Ba Khin</p>
# </div>
# </header>
# </div>
# <div class="hidden-xs">
# <ul class="nav nav-pills" id="navbar">
# <li id="nav-home">
# <a class="dropdown-toggle" data-original-title="Home" href="/en-US/index" title="">
# <i class="glyphicon glyphicon-home"></i>
# </a> </li>
# <li class=" dropdown" id="nav-about">
# <a class="dropdown-toggle" href="/en-US/about/vipassana">About</a>
# <ul class="dropdown-menu" id="about-menu" style="left: -38px;">
# <li><a href="/en-US/about/vipassana">What is Vipassana?</a></li>
# <li><a href="/en-US/about/goenka">Mr. S.N. Goenka</a></li>
# <li><a href="/en-US/about/art">The Art of Living: Vipassana Meditation</a></li>
# <li><a href="/en-US/about/code">The Code of Discipline</a></li>
# <li><a href="/en-US/about/qanda">Questions &amp; Answers About the Technique of Vipassana Meditation</a></li>
# </ul>
# </li>
# <li class="dropdown" id="nav-courses">
# <a class="dropdown-toggle" href="/en-US/courses/search" rel="nofollow">Courses</a>
# <ul class="dropdown-menu" id="courses-menu" style="left: -38px;">
# <li>
# <a href="/en-US/courses/search" rel="nofollow">Search</a>
# </li>
# <li class="dropdown">
# <a href="/en-US/courses/glossary" rel="nofollow">Glossary</a>
# </li>
# </ul>
# </li>
# <li class="dropdown" id="nav-locations">
# <a href="/en-US/locations/directory" rel="nofollow">Locations</a>
# <ul class="dropdown-menu" id="resources-menu" style="left: -37.5px;">
# <li>
# <a href="/en-US/locations/directory" rel="nofollow">Worldwide Directory</a>
# </li>
# <li class="dropdown">
# <a href="/en-US/maps#001" rel="nofollow">Maps</a>
# </li>
# <li><a href="/en-US/locations/contacts" rel="nofollow">Contacts</a></li>
# </ul>
# </li>
# <li class="dropdown" id="nav-special-sites">
# <a class="dropdown-toggle" href="#">Special Sites</a>
# <ul class="dropdown-menu" id="special-sites-menu" style="left: -34px;">
# <li><a href="/os/" target="_blank">For Old Students</a></li>
# <li><a href="http://www.executive.dhamma.org/" target="_blank">Vipassana for Executives</a></li>
# <li>
# <a href="http://www.prison.dhamma.org/" target="_blank">Vipassana for Prisons</a>
# </li>
# <li>
# <a href="http://www.children.dhamma.org/" target="_blank">Children's Courses</a>
# </li>
# <li><a href="https://www.dhamma.org/en/vri.htm" target="_blank">Vipassana Research Institute</a></li>
# <li><a href="https://www.dhamma.org/en/global.htm" target="_blank">Global Vipassana Pagoda</a></li>
# <li><a href="/en-US/about/mini_anapana">Mini Anapana Meditation</a></li>
# <li><a href="/en-US/about/more_language_sites">More Language Sites</a></li>
# </ul>
# </li>
# <li id="nav-language">
# <a href="#set-language">
# <i class="glyphicon glyphicon-globe"></i> U.S. English
# </a>
# <div class="panel panel-default" id="select-language">
# <div class="panel-body">
# <h3>Select Language</h3>
# <ul id="select-language-list">
# <li><a href="/bg/courses/search">български</a></li>
# <li><a href="/cs/courses/search">čeština</a></li>
# <li><a href="/de/courses/search">Deutsch</a></li>
# <li><a href="/el/courses/search">Ελληνικά</a></li>
# <li><a href="/en/courses/search">English</a></li>
# <li><a href="/en-US/courses/search">U.S. English</a></li>
# <li><a href="/es/courses/search">Español</a></li>
# <li><a href="/fa/courses/search">فارسی</a></li>
# <li><a href="/fi/courses/search">Suomi</a></li>
# <li><a href="/fr/courses/search">Français</a></li>
# <li><a href="/fr-CA/courses/search">Français canadien</a></li>
# </ul><ul>
# <li><a href="/gu/courses/search">ગુજરાતી</a></li>
# <li><a href="/he/courses/search">עברית</a></li>
# <li><a href="/hi/courses/search">हिन्दी</a></li>
# <li><a href="/hu/courses/search">Magyar</a></li>
# <li><a href="/id/courses/search">Bahasa Indonesia</a></li>
# <li><a href="/it/courses/search">Italiano</a></li>
# <li><a href="/it-CH/courses/search">Svizzero Italiano</a></li>
# <li><a href="/ja/courses/search">日本語</a></li>
# <li><a href="/km/courses/search">ភាសាខ្មែរ</a></li>
# <li><a href="/ko/courses/search">한국어</a></li>
# <li><a href="/lt/courses/search">Lietuvių</a></li>
# </ul><ul>
# <li><a href="/lv/courses/search">Latviešu</a></li>
# <li><a href="/mk/courses/search">македонски</a></li>
# <li><a href="/mr/courses/search">मराठी</a></li>
# <li><a href="/ne/courses/search">नेपाली</a></li>
# <li><a href="/nl/courses/search">Nederlands</a></li>
# <li><a href="/pl/courses/search">Polski</a></li>
# <li><a href="/pt/courses/search">Português</a></li>
# <li><a href="/pt-BR/courses/search">Português do Brasil</a></li>
# <li><a href="/ro/courses/search">Română</a></li>
# <li><a href="/ru/courses/search">русский</a></li>
# </ul><ul>
# <li><a href="/si/courses/search">සිංහල</a></li>
# <li><a href="/sr/courses/search">Српски</a></li>
# <li><a href="/sv/courses/search">Svenska</a></li>
# <li><a href="/ta/courses/search">தமிழ்</a></li>
# <li><a href="/te/courses/search">తెలుగు</a></li>
# <li><a href="/th/courses/search">ไทย</a></li>
# <li><a href="/tr/courses/search">Türkçe</a></li>
# <li><a href="/vi/courses/search">Tiếng Việt</a></li>
# <li><a href="/zh-HANS/courses/search">简体字</a></li>
# <li><a href="/zh-HANT/courses/search">繁體字</a></li>
# </ul>
# <div class="clearfix"></div>
# <hr/>
# <p>Translations are in progress. Some pages may have a mix of your selected language and English.</p>
# <br/>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </section>
# <section id="main">
# <br/>
# <section class="tabbed-header">
# <h2>
# Courses
# <small class="icon hidden-xs"><a data-content='&lt;span class="notes-title"&gt;To find a course:&lt;/span&gt; &amp;nbsp;&amp;nbsp;&amp;nbsp; 1. (Optional) Enter one or more search criteria in the boxes &amp;nbsp;&amp;nbsp;&amp;nbsp; 2. Click the blue search button.&lt;br /&gt;
# &lt;br type="_moz" /&gt;&lt;hr /&gt;&lt;div&gt;
# 	How to locate and apply for courses:  &lt;/div&gt;
# &lt;div&gt;
# 	&lt;ul&gt;
# 		&lt;li&gt;
# 			Select an applicable tab, refine the search options by specifying one or more values per box (re-click the same box to specify additional values) and press the search button&lt;/li&gt;
# 		&lt;li&gt;
# 			Find a suitable course from the list of available courses and click the Apply button to access the online application form in the language of your choice (only the top 100 results are returned; if you do not find a suitable course from the returned result set then refine the search options further and reissue the search)&lt;/li&gt;
# 		&lt;li&gt;
# 			Read carefully the Introduction to the Technique and Code of Discipline which you will be asked to follow during your course.  Fully and completely fill out all the sections of application form and submit it.  An application is required to register for all courses.&lt;/li&gt;
# 		&lt;li&gt;
# 			Await notification.  All correspondence will be through e-mail if you give an e-mail address in your application. Due to the large volume of applications, it may take several weeks before receiving notification.&lt;/li&gt;
# 		&lt;li&gt;
# 			If your application is accepted then we require you to confirm you will be attending in order to secure your place in the course.&lt;/li&gt;
# 	&lt;/ul&gt;
# &lt;/div&gt;' data-html="true" data-original-title="" data-placement="left" data-toggle="popover" href="#" title=""><i class="glyphicon glyphicon-question-sign"></i></a></small>
# </h2>
# <div id="course-search">
# <ul class="hidden-xs nav nav-tabs nav-quarters" id="student-type-select">
# <li class="active" data-bind="css: {active: current_state() == 'NewStudents'}, click: search_new_students">
# <a class="new-student" href="#">For New Students</a></li>
# <li class="" data-bind="css: {active: current_state() == 'OldStudents'}, click: search_old_students">
# <a class="old-student" href="#">For Old Students</a></li>
# <li class="" data-bind="css: {active: current_state() == 'Children'}, click: search_children">
# <a class="child" href="#">For Children/Teens</a></li>
# <li class="" data-bind="css: {active: current_state() == 'Executives'}, click: search_executives">
# <a class="executive" href="#">For Executives</a></li>
# </ul>
# <div class="search-panel" id="course-search-panel">
# <div id="search-panel-form">
# <div class="row">
# <div class="col-sm-10" id="search-panel-form-inputs">
# <div class="row">
# <div class="col-sm-4 visible-xs form-group">
# <select class="form-control" data-bind="event: { change: change_search_mode }" id="student-type-select-mobile">
# <option value="NewStudents">For New Students</option>
# <option value="OldStudents">For Old Students</option>
# <option value="Children">For Children/Teens</option>
# <option value="Executives">For Executives</option>
# </select>
# </div>
# <div class="col-sm-4 form-group" data-bind="css: {'has-error': dates_invalid}">
# <input class="form-control date" data-bind="daterangepicker: {separator: ' \u2014 ', arrows: true, showDropdowns: true,
#           format: date_format(), locale: { applyLabel: 'Confirm',
# ...
# </select>
# </div>
# </div>, <div class="col-sm-4 visible-xs form-group">
# <select class="form-control" data-bind="event: { change: change_search_mode }" id="student-type-select-mobile">
# <option value="NewStudents">For New Students</option>
# <option value="OldStudents">For Old Students</option>
# <option value="Children">For Children/Teens</option>
# <option value="Executives">For Executives</option>
# </select>
# </div>, <div class="col-sm-4 form-group" data-bind="css: {'has-error': dates_invalid}">
# <input class="form-control date" data-bind="daterangepicker: {separator: ' \u2014 ', arrows: true, showDropdowns: true,
#           format: date_format(), locale: { applyLabel: 'Confirm',
#           cancelLabel: 'Cancel', fromLabel: 'from',
#           toLabel: 'to' }}, value: search_daterange" id="course-search-date-range" placeholder="Select Date Range"/>
# </div>, <div class="col-sm-4">
# <div class="form-group">
# <div class="select2-container select2-container-multi form-control" id="s2id_loc_search"><ul class="select2-choices"> <li class="select2-search-field"> <label class="select2-offscreen" for="s2id_autogen1"></label> <input autocapitalize="off" autocomplete="off" autocorrect="off" class="select2-input select2-default" id="s2id_autogen1" placeholder="" spellcheck="false" style="width: 222px;" type="text"/> </li></ul><div class="select2-drop select2-drop-multi select2-display-none"> <ul class="select2-results"> <li class="select2-no-results">No matches found</li><li class="select2-no-results">No matches found</li><li class="select2-no-results">No matches found</li></ul></div></div><input class="form-control" data-bind="select2ValueUpdate: search_region, select2: select2_config_region()" id="loc_search" placeholder="State/Province, Country, Region" style="display: none;" tabindex="-1" type="hidden" value=""/>
# </div>
# </div>, <div class="form-group">
# <div class="select2-container select2-container-multi form-control" id="s2id_loc_search"><ul class="select2-choices"> <li class="select2-search-field"> <label class="select2-offscreen" for="s2id_autogen1"></label> <input autocapitalize="off" autocomplete="off" autocorrect="off" class="select2-input select2-default" id="s2id_autogen1" placeholder="" spellcheck="false" style="width: 222px;" type="text"/> </li></ul><div class="select2-drop select2-drop-multi select2-display-none"> <ul class="select2-results"> <li class="select2-no-results">No matches found</li><li class="select2-no-results">No matches found</li><li class="select2-no-results">No matches found</li></ul></div></div><input class="form-control" data-bind="select2ValueUpdate: search_region, select2: select2_config_region()" id="loc_search" placeholder="State/Province, Country, Region" style="display: none;" tabindex="-1" type="hidden" value=""/>
# </div>, <div class="select2-container select2-container-multi form-control" id="s2id_loc_search"><ul class="select2-choices"> <li class="select2-search-field"> <label class="select2-offscreen" for="s2id_autogen1"></label> <input autocapitalize="off" autocomplete="off" autocorrect="off" class="select2-input select2-default" id="s2id_autogen1" placeholder="" spellcheck="false" style="width: 222px;" type="text"/> </li></ul><div class="select2-drop select2-drop-multi select2-display-none"> <ul class="select2-results"> <li class="select2-no-results">No matches found</li><li class="select2-no-results">No matches found</li><li class="select2-no-results">No matches found</li></ul></div></div>, <div class="select2-drop select2-drop-multi select2-display-none"> <ul class="select2-results"> <li class="select2-no-results">No matches found</li><li class="select2-no-results">No matches found</li><li class="select2-no-results">No matches found</li></ul></div>, <div class="col-sm-4">
# <div class="select2-container select2-container-multi form-control" id="s2id_language-filter"><ul class="select2-choices"> <li class="select2-search-field"> <label class="select2-offscreen" for="s2id_autogen2"></label> <input autocapitalize="off" autocomplete="off" autocorrect="off" class="select2-input select2-default" id="s2id_autogen2" placeholder="" spellcheck="false" style="width: 222px;" type="text"/> </li></ul><div class="select2-drop select2-drop-multi select2-display-none"> <ul class="select2-results"> <li class="select2-no-results">No matches found</li><li class="select2-no-results">No matches found</li></ul></div></div><select class="form-control" data-bind="select2: {placeholder: 'Select Course Language'}, options: instruction_languages, optionsText: 'description', optionsValue: 'iso_code', selectedOptions: search_languages" id="language-filter" multiple="" style="display: none;" tabindex="-1"><option value="af">Afrikaans</option><option value="am">Amharic</option><option value="ar">Arabic</option><option value="bn">Bengali</option><option value="bg">Bulgarian</option><option value="my">Burmese</option><option value="yue">Cantonese</option><option value="cs">Czech</option><option value="da">Danish</option><option value="nl">Dutch</option><option value="en">English</option><option value="fi">Finnish</option><option value="fr">French</option><option value="de">German</option><option value="el">Greek</option><option value="gu">Gujarati</option><option value="hak">Hakka</option><option value="he">Hebrew</option><option value="hi">Hindi</option><option value="hu">Hungarian</option><option value="id">Indonesian</option><option value="it">Italian</option><option value="ja">Japanese</option><option value="kn">Kannada</option><option value="km">Khmer</option><option value="ko">Korean</option><option value="lv">Latvian</option><option value="lt">Lithuanian</option><option value="ml">Malayalam</option><option value="cmn">Mandarin</option><option value="mr">Marathi</option><option value="mon">Mon</option><option value="mn">Mongolian</option><option value="ne">Nepali</option><option value="new">Newari</option><option value="no">Norwegian</option><option value="fa">Persian (Farsi)</option><option value="pl">Polish</option><option value="pt">Portuguese</option><option value="pa">Punjabi</option><option value="ro">Romanian</option><option value="ru">Russian</option><option value="sr">Serbian</option><option value="hbs">Serbo-Croatian</option><option value="shn">Shan</option><option value="si">Sinhala</option><option value="sl">Slovenian</option><option value="es">Spanish</option><option value="sw">Swahili</option><option value="sv">Swedish</option><option value="tl">Tagalog</option><option value="ta">Tamil</option><option value="te">Telugu</option><option value="th">Thai</option><option value="tr">Turkish</option><option value="vi">Vietnamese</option>
# </select>
# </div>, <div class="select2-container select2-container-multi form-control" id="s2id_language-filter"><ul class="select2-choices"> <li class="select2-search-field"> <label class="select2-offscreen" for="s2id_autogen2"></label> <input autocapitalize="off" autocomplete="off" autocorrect="off" class="select2-input select2-default" id="s2id_autogen2" placeholder="" spellcheck="false" style="width: 222px;" type="text"/> </li></ul><div class="select2-drop select2-drop-multi select2-display-none"> <ul class="select2-results"> <li class="select2-no-results">No matches found</li><li class="select2-no-results">No matches found</li></ul></div></div>, <div class="select2-drop select2-drop-multi select2-display-none"> <ul class="select2-results"> <li class="select2-no-results">No matches found</li><li class="select2-no-results">No matches found</li></ul></div>, <div class="row">
# <!-- ko if: showAdvancedOptions --><!-- /ko -->
# <!-- ko if: current_state() == 'OldStudents' --><!-- /ko -->
# <div class="col-sm-4">
# </div>
# </div>, <div class="col-sm-4">
# </div>, <div class="col-sm-2">
# <a class="btn btn-apply center" data-bind="click: performSearch" href="/search" style="width:100%;">
# <i class="glyphicon glyphicon-search"></i></a>
# <!-- ko if: share() --><!-- /ko -->
# </div>, <div class="search-toolbar btn-toolbar" id="course-list-setting">
# <!-- ko if: results_on_search --><!-- /ko -->
# </div>, <div id="course-search-instructions">
# <!-- ko if: current_state() == 'NewStudents' -->
# <p>
# <a name="10-Day"></a> <span class="notes-title">10-day Courses</span> are an introductory course to Vipassana Meditation where the technique is taught step-by-step each day. The courses begin after a 2 - 4 pm registration period and orientation, followed by 10 full days of meditation, and end the morning of the 11th day by 7:30 am.</p>
# <!-- /ko -->
# <!-- ko if: current_state() == 'OldStudents' --><!-- /ko -->
# <!-- ko if: current_state() == 'Children' --><!-- /ko -->
# <!-- ko if: current_state() == 'Executives' --><!-- /ko -->
# </div>, <div id="location-modal-container"></div>, <div id="footer">
# <hr/>
# <p>
# Dhamma.org
# </p>
# <p>
# <a href="/en-US/about/privacy">Privacy Policy</a>
# |
# <a href="mailto:webmaster@dhamma.org">Email Webmaster</a>
# </p>
# <p>
# <a href="https://itunes.apple.com/us/app/dhamma-org/id1127952631?mt=8"><img alt="App store us uk" src="/assets/app-store-us-uk-475b9d8be87e34a116c3763a3640c26f.svg" width="135"/></a>
# <a href="https://play.google.com/store/apps/details?id=org.dhamma"><img alt="Play store badge" src="/assets/play-store-badge-fd9ac7cfac52af3d94574d52ae0f29d9.png" width="155"/></a> </p>
# <p>
# <a href="/en-US/about/mobile-app">Dhamma.org Mobile App</a>
# </p>
# </div>, <div class="daterangepicker dropdown-menu opensright" style="top: 420.2px; left: 68.8px; right: auto;"><div class="calendar-container left"><div class="daterangepicker_start_input"><label for="daterangepicker_start">from</label><input class="form-control input-mini" disabled="" name="daterangepicker_start" style="text-align:center;" type="text" value=""/></div><div class="calendar left" style="display: block;"><div class="calendar-date"><table class="table-condensed"><thead><tr><th class="prev available"><i class="icon-arrow-left glyphicon glyphicon-arrow-left"></i></th><th colspan="5" style="width: auto"><select class="monthselect"><option value="0">Jan</option><option value="1">Feb</option><option value="2">Mar</option><option value="3">Apr</option><option value="4">May</option><option value="5">Jun</option><option value="6">Jul</option><option value="7">Aug</option><option value="8">Sep</option><option value="9">Oct</option><option selected="selected" value="10">Nov</option><option value="11">Dec</option></select><select class="yearselect"><option value="1968">1968</option><option value="1969">1969</option><option value="1970">1970</option><option value="1971">1971</option><option value="1972">1972</option><option value="1973">1973</option><option value="1974">1974</option><option value="1975">1975</option><option value="1976">1976</option><option value="1977">1977</option><option value="1978">1978</option><option value="1979">1979</option><option value="1980">1980</option><option value="1981">1981</option><option value="1982">1982</option><option value="1983">1983</option><option value="1984">1984</option><option value="1985">1985</option><option value="1986">1986</option><option value="1987">1987</option><option value="1988">1988</option><option value="1989">1989</option><option value="1990">1990</option><option value="1991">1991</option><option value="1992">1992</option><option value="1993">1993</option><option value="1994">1994</option><option value="1995">1995</option><option value="1996">1996</option><option value="1997">1997</option><option value="1998">1998</option><option value="1999">1999</option><option value="2000">2000</option><option value="2001">2001</option><option value="2002">2002</option><option value="2003">2003</option><option value="2004">2004</option><option value="2005">2005</option><option value="2006">2006</option><option value="2007">2007</option><option value="2008">2008</option><option value="2009">2009</option><option value="2010">2010</option><option value="2011">2011</option><option value="2012">2012</option><option value="2013">2013</option><option value="2014">2014</option><option value="2015">2015</option><option value="2016">2016</option><option value="2017">2017</option><option selected="selected" value="2018">2018</option><option value="2019">2019</option><option value="2020">2020</option><option value="2021">2021</option><option value="2022">2022</option><option value="2023">2023</option></select></th><th class="next available"><i class="icon-arrow-right glyphicon glyphicon-arrow-right"></i></th></tr><tr><th>Su</th><th>Mo</th><th>Tu</th><th>We</th><th>Th</th><th>Fr</th><th>Sa</th></tr></thead><tbody><tr><td class="available off" data-title="r0c0">28</td><td class="available off" data-title="r0c1">29</td><td class="available off" data-title="r0c2">30</td><td class="available off" data-title="r0c3">31</td><td class="available" data-title="r0c4">1</td><td class="available" data-title="r0c5">2</td><td class="available" data-title="r0c6">3</td></tr><tr><td class="available" data-title="r1c0">4</td><td class="available" data-title="r1c1">5</td><td class="available" data-title="r1c2">6</td><td class="available" data-title="r1c3">7</td><td class="available" data-title="r1c4">8</td><td class="available" data-title="r1c5">9</td><td class="available" data-title="r1c6">10</td></tr><tr><td class="available" data-title="r2c0">11</td><td class="available" data-title="r2c1">12</td><td class="a ...
